# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("/content/INM713_coursework_data_pizza_8358_1_reduced.csv")

# Check for NaN values in each column
nan_values = df.isnull().sum()
print("NaN values per column:")
print(nan_values)

# Explore the 'categories' column and extract unique category values
categories_column = df['categories']
categories = set()

# Iterate over each row in the 'categories' column
for row in categories_column:
    if isinstance(row, str):
        # Split the row by commas and add each category to the set
        row_categories = row.split(',')
        for category in row_categories:
            categories.add(category.strip())

# Print unique category values
print("Unique category values:")
for category in categories:
    print(category)
# Out:
# NaN values per column:
# name                   0
# address                0
# city                   0
# country                0
# postcode              65
# state                  0
# categories             0
# menu item              0
# item value           562
# currency             559
# item description    1984
# dtype: int64
# Unique category values:
#
# Brazilian Restaurants
# Bar Heart of Missoula
# Sporting Goods Shop and Shoe Store
# Pizza Place East Bronx
# Miscellaneous Shop
# Seafood Restaurant
# Medicine
# Pizza Place and American Restaurant
# Ice Cream Shop
# Middle Eastern Restaurants
# Sales Promotions & Counseling Services
# Bowling Alley
# cafe
# Wigs & Hair Pieces
# dresses
# and Wine Bar
# Pizza Place Downtown Destin
# Gas Stations
# Adult Entertainers
# Cajun / Creole Restaurant
# Pizza Place and Mexican Restaurant
# Convenience Store
# Take Out
# cuisine - seafood
# Hospices
# Italian Restaurant and Pizza Place West Hills
# Bar and Gastropub
# Video Rental & Sales
# Mckeesport Restaurants
# Caterers
# Breakfast Spot
# Gourmet Restaurants
# sports bar
# Event Planning
# Wedding Reception Locations & Services
# Music Venue
# Convention Services & Facilities
# Cadillac Restaurants
# Creole & Cajun Restaurants
# Vietnamese Restaurant
# Lodging
# American Restaurant Rose Hill
# Restaurants
# Movie Theater
# Sandwiches
# Japanese Restaurant South Redondo Beach
# TX\\Mexican Restaurant
# Take Out Restaurants
# Pizza Place Northwest Davenport
# and Fast Food Restaurant LoDo
# Chicken Restaurants
# Arcade
# German Restaurant
# and Beer Garden
# Beer and Ale
# American Restaurant and BBQ Joint
# Video Store
# Pizza Place LoDo
# American Restaurant and Sports Bar
# Bed and Breakfast and Inns
# Multiplex
# Cuban Restaurant
# Health Food Restaurants
# French Restaurant Metro West
# Hotels Motels
# American Restaurant and Asian Restaurant
# Pub and Restaurant
# Sports Bar Riverside
# Salad Place
# Automotive
# Southern / Soul Food Restaurant
# American Restaurant and French Restaurant
# and Gluten-free Restaurant
# Sportswear
# Beer Taverns & Pubs
# University University
# recreation
# Speakeasy
# and Karaoke Bar
# Texas (tx)
# Mini Golf
# mexican restaurant
# Gastropub
# Sandwich Place and Deli / Bodega
# Italian
# DVD Sales & Service
# Pizza Place Southwest Dallas
# Greek Restaurant
# Chinese Restaurant Wynnewood
# pizza place
# Clothing Store
# Bakeries
# Sports Bar
# Breakfast
# Steakhouse
# Fish Chips Shop and Fried Chicken Joint Northwest Davenport
# and Coffee Shop
# Pizza Place Northwest Side
# Burger Joint and American Restaurant
# feature - Outdoor Dining
# Italian Restaurant and Pizza Place
# Italian Restaurant Anthem
# Coffee Shop and Caf
# office
# fashion
# Food North Raleigh
# and Music Venue
# Winery
# Conventions
# Sports Bars
# Middle Eastern Restaurant
# Fast Food Restaurants
# Bars Clubs
# Supermarkets and Super Stores
# Brewery
# American (traditional) Seafood
# and Pizza Place
# Banquet Rooms
# feature - Fireplace
# flower girl dresses
# Wings Joint
# Diner
# Coffee Shop
# Irish
# feature - Online Reservations
# Greek Restaurant and Fast Food Restaurant
# Studio City
# Italian Grocery Stores
# Italian Foods
# Electronic Equipment & Supplies Service & Repair
# meal - Brunch
# business attorneys
# Designer Clothing & Accessories
# Tea Room
# Chinese Restaurants
# meal - Lunch
# Spanish Restaurant
# casual dining
# and Go Kart Track
# ;area - brooklyn
# Cell Phone Service
# labor organizations
# meal - Dinner
# American Restaurant and Italian Restaurant
# Food Products
# Deli / Bodega and Convenience Store
# Doors
# Beer Store
# Vehicle Service and Repair
# Food & Entertainment
# Lingerie Store and Women's Store
# Clothing Stores
# Amusement Devices
# Coffee Shops
# Barbecue Restaurants

# %%
# Explore the 'categories' column and extract unique category values
categories_column = df['categories']
categories = []

# Iterate over each row in the 'categories' column
for row in categories_column:
    if isinstance(row, str):
        # Split the row by commas and add each category to the list
        row_categories = row.split(',')
        for category in row_categories:
            categories.append(category.strip())

# Create a pandas Series from the categories list and get the top 10 most frequent categories
top_10_categories = pd.Series(categories).value_counts().head(25)

# Print the top 10 most frequent categories
print("Top 10 most frequent categories:")
print(top_10_categories)
# Out:
# Top 10 most frequent categories:
# Pizza Place                                   1587
# Restaurants                                   1120
# Restaurant                                     884
# Pizza                                          827
# Italian Restaurant                             551
# Caterers                                       383
# Italian Restaurants                            370
# Take Out Restaurants                           350
# American Restaurant                            339
# Bar                                            184
# Pizza Place and Italian Restaurant             110
# Mediterranean Restaurants                       84
# Sports Bar                                      83
# Sandwich Shops                                  77
# American Restaurants                            76
# Delicatessens                                   59
# American Restaurant and Italian Restaurant      55
# Bars                                            53
# Family Style Restaurants                        51
# Food & Entertainment                            51
# Pizza Restaurants                               50
# Mexican Restaurant                              47
# Food and Beverage                               45
# Catering                                        42
# Bar & Grills                                    42
# dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all the menu items into a single string
menu_items = ' '.join(df['menu item'].dropna().values.tolist())
modified_text = menu_items.replace("pizza", "")
modified_text = modified_text.replace("Pizza", "")
# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(modified_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from collections import Counter

text = modified_text

# Convert the string to lowercase and split it into words
words = text.lower().split()

# Count the occurrences of each word
word_counts = Counter(words)

# Get the top 20 most common words
top_20_words = word_counts.most_common(100)

# Print the top 20 words and their counts
for word, count in top_20_words:
    print(f"{word}: {count}")
# Out:
# cheese: 353
# chicken: 292
# white: 135
# margherita: 115
# pepperoni: 105
# bbq: 97
# the: 97
# crust: 80
# steak: 79
# thin: 78
# veggie: 77
# hawaiian: 75
# large: 74
# stuffed: 73
# burger: 73
# buffalo: 70
# slice: 67
# and: 63
# meat: 61
# bread: 61
# sicilian: 56
# your: 55
# own: 53
# sub: 52
# topping: 51
# gourmet: 45
# taco: 43
# s: 43
# of: 41
# greek: 41
# flatbread: 39
# fries: 38
# breakfast: 37
# or: 37
# medium: 36
# mexican: 34
# bacon: 33
# by: 32
# with: 31
# special: 31
# vegetarian: 30
# sausage: 30
# mushroom: 29
# vegetable: 28
# margarita: 28
# philly: 28
# supreme: 27
# create: 26
# tomato: 26
# specialty: 26
# pesto: 25
# deep: 25
# iola: 25
# lovers: 25
# prosciutto: 25
# 1: 25
# broccoli: 24
# sauce: 23
# mini: 23
# pita: 23
# shrimp: 23
# grilled: 23
# 2: 23
# toppings: 22
# build: 22
# spicy: 22
# bagel: 20
# deluxe: 20
# dish: 20
# mediterranean: 20
# any: 20
# bianca: 19
# con: 19
# free: 19
# four: 19
# ,: 18
# spinach: 18
# gluten: 18
# pan: 18
# roll: 17
# plain: 17
# chicago: 17
# classic: 17
# new: 17
# roasted: 17
# style: 16
# alfredo: 16
# personal: 16
# ranch: 16
# mozzarella: 16
# (medium): 16
# (small): 16
# crust): 16
# slices: 15
# kids: 15
# original: 15
# garlic: 15
# whole: 15
# cheeseburger: 15
# (reg: 15

# %%
type(menu_items)
# Out:
# str

# %%
import pandas as pd
import re


# Extract the pizza types from the 'menu item' column using regular expressions
pizza_types = df['menu item'].str.extract(r'(cheese|veggie|pepperoni|margherita|hawaiian|meat lovers|bbq chicken|supreme|buffalo chicken|greek)', flags=re.IGNORECASE)

# Assign 'Other' category to remaining pizza types
pizza_types = pizza_types.fillna('Other')

# Add the pizza type column to the DataFrame
df['pizza_type'] = pizza_types

# Count the occurrences of each pizza type
pizza_type_counts = pizza_types[0].value_counts()

# Get the top 10 pizza types
top_10_pizza_types = pizza_type_counts.head(10)

# Print the top 10 pizza types
print("Top 10 pizza types:")
print(top_10_pizza_types)

# Print the updated DataFrame with the pizza type column
print("Updated DataFrame:")
df.head(10)
# Out:
# Top 10 pizza types:
# Other              2548
# Cheese              374
# Margherita          115
# Pepperoni           103
# Hawaiian             75
# Veggie               75
# Bbq Chicken          73
# Buffalo Chicken      57
# Greek                41
# Supreme              25
# Name: 0, dtype: int64
# Updated DataFrame:
#                     name                                  address  \
# 0  Little Pizza Paradise  Cascade Village Mall Across From Target
# 1  Little Pizza Paradise  Cascade Village Mall Across From Target
# 2          The Brentwood                     148 S Barrington Ave
# 3          The Brentwood                     148 S Barrington Ave
# 4          The Brentwood                     148 S Barrington Ave
# 5          The Brentwood                     148 S Barrington Ave
# 6          The Brentwood                     148 S Barrington Ave
# 7  Bravo Pizza Hollywood                      5142 Hollywood Blvd
# 8  Bravo Pizza Hollywood                      5142 Hollywood Blvd
# 9  Bravo Pizza Hollywood                      5142 Hollywood Blvd
#
#           city country postcode      state                      categories  \
# 0         Bend      US    97701         OR                     Pizza Place
# 1         Bend      US    97701         OR                     Pizza Place
# 2  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 3  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 4  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 5  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 6  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 7  Los Angeles      US    90027  Los Feliz                     Pizza Place
# 8  Los Angeles      US    90027  Los Feliz                     Pizza Place
# 9  Los Angeles      US    90027  Los Feliz                     Pizza Place
#
#                          menu item  item value currency  \
# 0                     Bianca Pizza       22.50      USD
# 1                     Cheese Pizza       18.95      USD
# 2                Pizza, Margherita       12.00      USD
# 3                  Pizza, Mushroom       13.00      USD
# 4                Pizza, Puttenesca       13.00      USD
# 5           Pizza, Salami Piccante       15.00      USD
# 6  Pizza, White Truffle Meat Sauce       15.00      USD
# 7                     Cheese Pizza       10.99      USD
# 8                   Hawaiian Pizza       11.99      USD
# 9                 Meat Lover Pizza       16.99      USD
#
#                    item description  pizza_type
# 0                               NaN       Other
# 1                               NaN      Cheese
# 2                               NaN  Margherita
# 3                               NaN       Other
# 4  Olives, onions, capers, tomatoes       Other
# 5                               NaN       Other
# 6                               NaN       Other
# 7              Choose a pizza size.      Cheese
# 8        Canadian bacon, pineapple.    Hawaiian
# 9                               NaN       Other

# %%
import pandas as pd



# Define the 50 pizza types
pizza_types = ['kid','margarita','vegetarian','vegetable','nutella','italian','grilled','sandwich','seafood','sushi','vodka','buffalo','bbq','bagel','roll','fries','burger','steak','bread','sub','crust','taco','mexican','bianca','shrimp','mediterranean','cheese','meat', 'veggie', 'margherita', 'pepperoni', 'hawaiian', 'meat lovers', 'supreme', 'bbq chicken', 'buffalo chicken', 'spinach', 'mushroom', 'pesto', 'neapolitan', 'sicilian', 'white', 'greek', 'anchovy', 'sausage', 'bacon', 'ham', 'chicken', 'artichoke', 'roasted garlic', 'tomato', 'prosciutto', 'four cheese', 'barbecue', 'ranch', 'garlic', 'onion', 'green pepper', 'red pepper', 'jalapeno', 'olive', 'pineapple', 'broccoli', 'feta', 'goat cheese', 'blue cheese', 'ricotta', 'mozzarella', 'parmesan', 'romano', 'asiago', 'cheddar', 'swiss', 'gorgonzola', 'brie', 'goat']

# Function to classify pizza based on its name
def classify_pizza(pizza_name):
    for pizza_type in pizza_types:
        if pizza_type in pizza_name.lower():
              return pizza_type

    return 'other'

# Apply the classification function to the 'name' column and create a new column 'pizza_type'
df['pizza_type'] = df['menu item'].apply(classify_pizza)

# Print the updated table
df.head(10)
# Out:
#                     name                                  address  \
# 0  Little Pizza Paradise  Cascade Village Mall Across From Target
# 1  Little Pizza Paradise  Cascade Village Mall Across From Target
# 2          The Brentwood                     148 S Barrington Ave
# 3          The Brentwood                     148 S Barrington Ave
# 4          The Brentwood                     148 S Barrington Ave
# 5          The Brentwood                     148 S Barrington Ave
# 6          The Brentwood                     148 S Barrington Ave
# 7  Bravo Pizza Hollywood                      5142 Hollywood Blvd
# 8  Bravo Pizza Hollywood                      5142 Hollywood Blvd
# 9  Bravo Pizza Hollywood                      5142 Hollywood Blvd
#
#           city country postcode      state                      categories  \
# 0         Bend      US    97701         OR                     Pizza Place
# 1         Bend      US    97701         OR                     Pizza Place
# 2  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 3  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 4  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 5  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 6  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 7  Los Angeles      US    90027  Los Feliz                     Pizza Place
# 8  Los Angeles      US    90027  Los Feliz                     Pizza Place
# 9  Los Angeles      US    90027  Los Feliz                     Pizza Place
#
#                          menu item  item value currency  \
# 0                     Bianca Pizza       22.50      USD
# 1                     Cheese Pizza       18.95      USD
# 2                Pizza, Margherita       12.00      USD
# 3                  Pizza, Mushroom       13.00      USD
# 4                Pizza, Puttenesca       13.00      USD
# 5           Pizza, Salami Piccante       15.00      USD
# 6  Pizza, White Truffle Meat Sauce       15.00      USD
# 7                     Cheese Pizza       10.99      USD
# 8                   Hawaiian Pizza       11.99      USD
# 9                 Meat Lover Pizza       16.99      USD
#
#                    item description  pizza_type
# 0                               NaN      bianca
# 1                               NaN      cheese
# 2                               NaN  margherita
# 3                               NaN    mushroom
# 4  Olives, onions, capers, tomatoes       other
# 5                               NaN       other
# 6                               NaN        meat
# 7              Choose a pizza size.      cheese
# 8        Canadian bacon, pineapple.    hawaiian
# 9                               NaN        meat

# %%
# Group by 'pizza_type' and count occurrences
pizza_counts = df.groupby('pizza_type').size().reset_index(name='count')

# Sort the counts in descending order
pizza_counts = pizza_counts.sort_values(by='count', ascending=False)

# Print the top 10 most repeated pizza types
pizza_counts.head(50)
# Out:
#        pizza_type  count
# 33          other   1294
# 10         cheese    306
# 60          white    117
# 11        chicken    111
# 24     margherita    107
# 4             bbq     95
# 6           bread     90
# 49          steak     88
# 9          burger     85
# 12          crust     82
# 35      pepperoni     80
# 25           meat     76
# 19       hawaiian     72
# 8         buffalo     70
# 58         veggie     69
# 50            sub     47
# 47       sicilian     43
# 16          greek     40
# 54           taco     40
# 13          fries     38
# 27        mexican     37
# 41           roll     33
# 57     vegetarian     32
# 56      vegetable     30
# 23      margarita     28
# 44        sausage     26
# 51        supreme     24
# 46         shrimp     23
# 17        grilled     23
# 29       mushroom     23
# 36          pesto     22
# 20        italian     20
# 5          bianca     20
# 2           bagel     20
# 22            kid     20
# 37     prosciutto     19
# 48        spinach     17
# 55         tomato     16
# 26  mediterranean     14
# 1           bacon     12
# 43       sandwich     12
# 45        seafood     12
# 52          sushi     11
# 7        broccoli      9
# 59          vodka      9
# 28     mozzarella      8
# 31        nutella      7
# 30     neapolitan      5
# 14         garlic      5
# 38          ranch      4

# %%
# Filter rows where pizza_type is 'other'
other_pizzas = df[df['pizza_type'] == 'other']

# Print the rows
DF=other_pizzas[['pizza_type','menu item']]
DF
# Out:
#      pizza_type               menu item
# 4         other       Pizza, Puttenesca
# 5         other  Pizza, Salami Piccante
# 13        other   Create Your Own Pizza
# 16        other        House Made Pizza
# 20        other   Pizza Con Uovo Fritto
# ...         ...                     ...
# 3492      other         Pastis De Pizza
# 3497      other    The New Yorker Pizza
# 3498      other          Personal Pizza
# 3499      other             Pizza Pizza
# 3507      other              Pita Pizza
#
# [1294 rows x 2 columns]

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all the menu items into a single string
menu_items = ' '.join(DF['menu item'].dropna().values.tolist())
modified_text = menu_items.replace("pizza", "")
modified_text = modified_text.replace("Pizza", "")
# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(modified_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

text = modified_text

# Convert the string to lowercase and split it into words
words = text.lower().split()

# Count the occurrences of each word
word_counts = Counter(words)

# Get the top 20 most common words
top_20_words = word_counts.most_common(10)

# Print the top 20 words and their counts
for word, count in top_20_words:
    print(f"{word}: {count}")
# Out:
# the: 75
# slice: 56
# your: 52
# own: 52
# large: 46
# topping: 42
# breakfast: 37
# s: 37
# by: 31
# of: 28

# %%
# Update pizza_type column
# Replace values in the 'pizza_type' column
df['pizza_type'] = df['pizza_type'].replace(['vegetarian', 'vegetable'], 'veggie')
# Replace values in the 'pizza_type' column
df['pizza_type'] = df['pizza_type'].replace('margarita', 'margherita')

# Print the updated DataFrame
df.head()
# Out:
#                     name                                  address  \
# 0  Little Pizza Paradise  Cascade Village Mall Across From Target
# 1  Little Pizza Paradise  Cascade Village Mall Across From Target
# 2          The Brentwood                     148 S Barrington Ave
# 3          The Brentwood                     148 S Barrington Ave
# 4          The Brentwood                     148 S Barrington Ave
#
#           city country postcode      state                      categories  \
# 0         Bend      US    97701         OR                     Pizza Place
# 1         Bend      US    97701         OR                     Pizza Place
# 2  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 3  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 4  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
#
#            menu item  item value currency                  item description  \
# 0       Bianca Pizza       22.50      USD                               NaN
# 1       Cheese Pizza       18.95      USD                               NaN
# 2  Pizza, Margherita       12.00      USD                               NaN
# 3    Pizza, Mushroom       13.00      USD                               NaN
# 4  Pizza, Puttenesca       13.00      USD  Olives, onions, capers, tomatoes
#
#    pizza_type
# 0      bianca
# 1      cheese
# 2  margherita
# 3    mushroom
# 4       other

# %%
# Filter rows where pizza_type is 'other'
other_pizzas = df[df['pizza_type'] == 'other']

# Print the rows
DF=other_pizzas[['pizza_type','menu item']]
DF
# Out:
#      pizza_type               menu item
# 4         other       Pizza, Puttenesca
# 5         other  Pizza, Salami Piccante
# 13        other   Create Your Own Pizza
# 16        other        House Made Pizza
# 20        other   Pizza Con Uovo Fritto
# ...         ...                     ...
# 3492      other         Pastis De Pizza
# 3497      other    The New Yorker Pizza
# 3498      other          Personal Pizza
# 3499      other             Pizza Pizza
# 3507      other              Pita Pizza
#
# [1294 rows x 2 columns]

# %%
# Group by 'pizza_type' and count occurrences
pizza_counts = df.groupby('pizza_type').size().reset_index(name='count')

# Sort the counts in descending order
pizza_counts = pizza_counts.sort_values(by='count', ascending=False)

# Print the top 10 most repeated pizza types
pizza_counts.head(50)
# Out:
#        pizza_type  count
# 32          other   1294
# 10         cheese    306
# 23     margherita    135
# 55         veggie    131
# 57          white    117
# 11        chicken    111
# 4             bbq     95
# 6           bread     90
# 48          steak     88
# 9          burger     85
# 12          crust     82
# 34      pepperoni     80
# 24           meat     76
# 19       hawaiian     72
# 8         buffalo     70
# 49            sub     47
# 46       sicilian     43
# 16          greek     40
# 53           taco     40
# 13          fries     38
# 26        mexican     37
# 40           roll     33
# 43        sausage     26
# 50        supreme     24
# 45         shrimp     23
# 28       mushroom     23
# 17        grilled     23
# 35          pesto     22
# 22            kid     20
# 20        italian     20
# 2           bagel     20
# 5          bianca     20
# 36     prosciutto     19
# 47        spinach     17
# 54         tomato     16
# 25  mediterranean     14
# 1           bacon     12
# 42       sandwich     12
# 44        seafood     12
# 51          sushi     11
# 7        broccoli      9
# 56          vodka      9
# 27     mozzarella      8
# 30        nutella      7
# 29     neapolitan      5
# 14         garlic      5
# 37          ranch      4
# 52          swiss      3
# 0       artichoke      3
# 38        ricotta      2

# %%
# !pip install requests --quiet
# !pip install rdflib  --quiet
# !pip install SPARQLWrapper  --quiet
# !pip install Owlready2  --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 43.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for Owlready2 (pyproject.toml) ... done

# %%
df.head()
# Out:
#                     name                                  address  \
# 0  Little Pizza Paradise  Cascade Village Mall Across From Target
# 1  Little Pizza Paradise  Cascade Village Mall Across From Target
# 2          The Brentwood                     148 S Barrington Ave
# 3          The Brentwood                     148 S Barrington Ave
# 4          The Brentwood                     148 S Barrington Ave
#
#           city country postcode      state                      categories  \
# 0         Bend      US    97701         OR                     Pizza Place
# 1         Bend      US    97701         OR                     Pizza Place
# 2  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 3  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
# 4  Los Angeles      US    90049  Brentwood  American Restaurant,Bar,Bakery
#
#            menu item  item value currency                  item description  \
# 0       Bianca Pizza       22.50      USD                               NaN
# 1       Cheese Pizza       18.95      USD                               NaN
# 2  Pizza, Margherita       12.00      USD                               NaN
# 3    Pizza, Mushroom       13.00      USD                               NaN
# 4  Pizza, Puttenesca       13.00      USD  Olives, onions, capers, tomatoes
#
#    pizza_type
# 0      bianca
# 1      cheese
# 2  margherita
# 3    mushroom
# 4       other

# %%
df.groupby('currency').size().reset_index(name='count')
# Out:
#   currency  count
# 0      USD   2951

# %%
address = df[['name', 'address']]
state = df[['city', 'state']]
country = df[['state', 'country']]
postcode = df[['name', 'postcode']]
Categories =df[['name', 'categories']]
pizza=df[['name', 'menu item','pizza_type']]
#price=df[[ 'menu item','item value','name']]
#currency=df[[ 'name','currency','menu item']]
pizza_type=df[[ 'menu item','pizza_type','name']]

# %%
currency=df[[ 'name','currency','menu item','pizza_type']]
price=df[[ 'menu item','item value','name','pizza_type']]

# %%
city = df[['name', 'city']]

# %%
item_description = df[['menu item', 'item description','name','pizza_type']]

# %%
# Define a list of the dataframes
df_list = [address, state, country,postcode,Categories,pizza,price,currency,pizza_type]

# %%
import pandas as pd

# create the initial DataFrame

# split the categories column by comma and create a new DataFrame with one row for each category
split_categories = Categories['categories'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('category')
new_Categories = Categories.drop('categories', axis=1).join(split_categories)
new_Categories
# group by the name column and join the categories with commas
#final_Categories = new_Categories.groupby('name')['category'].apply(','.join).reset_index()

#final_Categories
# Out:
#                        name             category
# 0     Little Pizza Paradise          Pizza Place
# 1     Little Pizza Paradise          Pizza Place
# 2             The Brentwood  American Restaurant
# 2             The Brentwood                  Bar
# 2             The Brentwood               Bakery
# ...                     ...                  ...
# 3507         Moonlight Cafe           Restaurant
# 3507         Moonlight Cafe   Italian Restaurant
# 3508         Moonlight Cafe           Restaurant
# 3508         Moonlight Cafe   Italian Restaurant
# 3509                 Guidos           Restaurant
#
# [10272 rows x 2 columns]

# %%
# Create an empty dataframe to store the merged data
merged_df = pd.DataFrame(columns=['subject', 'predicate', 'object'])

# Loop over each dataframe in the list
for i, DF in enumerate(df_list):

    # Extract the column names for the current dataframe
    col_names = list(DF.columns)

    # Create a copy of the dataframe with the column names replaced by 'subject' and 'object'
    subj_df = DF.rename(columns={col_names[0]: 'subject', col_names[1]: 'object'})

    # Add a new column to the dataframe with the predicate name
    subj_df['predicate'] = col_names[1]
    print(col_names[1])
    # Append the transformed dataframe to the merged dataframe
    merged_df = merged_df.append(subj_df, ignore_index=True)

# Print the final merged dataframe
merged_df
# Out:
# address
# state
# country
# postcode
# categories
# menu item
# item value
# currency
# pizza_type
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
# <ipython-input-73-afc3359db0ae>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(subj_df, ignore_index=True)
#                      subject   predicate  \
# 0      Little Pizza Paradise     address
# 1      Little Pizza Paradise     address
# 2              The Brentwood     address
# 3              The Brentwood     address
# 4              The Brentwood     address
# ...                      ...         ...
# 31585          Supreme Pizza  pizza_type
# 31586       Vegetarian Pizza  pizza_type
# 31587             Pita Pizza  pizza_type
# 31588        Steak Pizzaiola  pizza_type
# 31589            White Pizza  pizza_type
#
#                                         object pizza_type  \
# 0      Cascade Village Mall Across From Target        NaN
# 1      Cascade Village Mall Across From Target        NaN
# 2                         148 S Barrington Ave        NaN
# 3                         148 S Barrington Ave        NaN
# 4                         148 S Barrington Ave        NaN
# ...                                        ...        ...
# 31585                                  supreme        NaN
# 31586                                   veggie        NaN
# 31587                                    other        NaN
# 31588                                    steak        NaN
# 31589                                    white        NaN
#
#                                     name menu item
# 0                                    NaN       NaN
# 1                                    NaN       NaN
# 2                                    NaN       NaN
# 3                                    NaN       NaN
# 4                                    NaN       NaN
# ...                                  ...       ...
# 31585  Prison Brews Brewery & Restaurant       NaN
# 31586  Prison Brews Brewery & Restaurant       NaN
# 31587                     Moonlight Cafe       NaN
# 31588                     Moonlight Cafe       NaN
# 31589                             Guidos       NaN
#
# [31590 rows x 6 columns]

# %%
new_merged_df=merged_df.drop_duplicates()
new_merged_df
# Out:
#                      subject   predicate  \
# 0      Little Pizza Paradise     address
# 2              The Brentwood     address
# 7      Bravo Pizza Hollywood     address
# 13               Lucky's Pub     address
# 14            Roadhouse Cafe     address
# ...                      ...         ...
# 31585          Supreme Pizza  pizza_type
# 31586       Vegetarian Pizza  pizza_type
# 31587             Pita Pizza  pizza_type
# 31588        Steak Pizzaiola  pizza_type
# 31589            White Pizza  pizza_type
#
#                                         object pizza_type  \
# 0      Cascade Village Mall Across From Target        NaN
# 2                         148 S Barrington Ave        NaN
# 7                          5142 Hollywood Blvd        NaN
# 13                        801 Saint Emanuel St        NaN
# 14                                478 South St        NaN
# ...                                        ...        ...
# 31585                                  supreme        NaN
# 31586                                   veggie        NaN
# 31587                                    other        NaN
# 31588                                    steak        NaN
# 31589                                    white        NaN
#
#                                     name menu item
# 0                                    NaN       NaN
# 2                                    NaN       NaN
# 7                                    NaN       NaN
# 13                                   NaN       NaN
# 14                                   NaN       NaN
# ...                                  ...       ...
# 31585  Prison Brews Brewery & Restaurant       NaN
# 31586  Prison Brews Brewery & Restaurant       NaN
# 31587                     Moonlight Cafe       NaN
# 31588                     Moonlight Cafe       NaN
# 31589                             Guidos       NaN
#
# [16984 rows x 6 columns]

# %%
# !pip install rdflib
# Out:
# Requirement already satisfied: rdflib in /usr/local/lib/python3.10/dist-packages (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)

# %% [markdown]
# subtask3

# %%
# !pip install SPARQLWrapper
# Out:
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.10/dist-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)

# %% [markdown]
# extract entities 1st

# %% [markdown]
# Final below:

# %% [markdown]
# edit

# %%
import pandas as pd
from rdflib import Graph, URIRef, RDF, Literal, XSD, Namespace
from SPARQLWrapper import SPARQLWrapper, JSON
import requests

# function to get entity URI from DBPedia
def get_dbpedia_uri(entity):
    uri = ""
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    query = """select ?s where { ?s rdfs:label "%s"@en } limit 1""" % entity
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    for result in results["results"]["bindings"]:
        uri = result["s"]["value"]
    return uri

# function to get entity URI from Wikidata
def get_wikidata_uri(entity):
    uri = ""
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = """select ?s where { ?s skos:altLabel "%s"@en } limit 1""" % entity
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    for result in results["results"]["bindings"]:
        uri = result["s"]["value"]
    return uri

# function to get entity URI from Google's Knowledge Graph
def get_googlekg_uri(entity):
    uri = ""
    api_key = "YOUR_API_KEY"  # replace with your own API key
    service_url = "https://kgsearch.googleapis.com/v1/entities:search"
    params = {
        "query": entity,
        "key": api_key,
        "limit": 1,
        "indent": True
    }
    url = service_url + "?" + "&".join("%s=%s" % (k, v) for k, v in params.items())
    response = requests.get(url).json()
    for element in response["itemListElement"]:
        uri = element["result"]["@id"]
    return uri

# %%
from rdflib import Graph, URIRef, RDFS, Literal, XSD, Namespace, OWL

# %%
import pandas as pd
from rdflib import Graph, URIRef, RDF, Literal, XSD, Namespace
from SPARQLWrapper import SPARQLWrapper, JSON
import requests

# function to get entity URI from DBPedia
def get_dbpedia_uri(entity):
    uri = ""
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    query = """select ?s where { ?s rdfs:label "%s"@en } limit 1""" % entity
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    for result in results["results"]["bindings"]:
        uri = result["s"]["value"]
    return uri

# function to get entity URI from Wikidata
def get_wikidata_uri(entity):
    uri = ""
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = """select ?s where { ?s skos:altLabel "%s"@en } limit 1""" % entity
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    for result in results["results"]["bindings"]:
        uri = result["s"]["value"]
    return uri

# %%
import time
import pandas as pd
from rdflib import Graph, URIRef, RDF, Literal, XSD, Namespace, OWL
from SPARQLWrapper import SPARQLWrapper, JSON
import requests
from urllib.error import HTTPError
import urllib.parse #for parsing strings to URI's

g = Graph()
country = country.dropna()
country = country.drop_duplicates()
n=Namespace('http://www.city.ac.uk/ds/inm713/hadi_ghasemi/')

def search_entity(entity):
    max_retries = 3
    retries = 0
    while retries < max_retries:
        try:
            uri = get_dbpedia_uri(entity)
            if uri:
                return uri
            time.sleep(1)  # add a delay to avoid too many requests
            uri = get_wikidata_uri(entity)
            if uri:
                return uri
            return None
        except HTTPError as ex:
            if ex.code == 429:
                print("Too many requests. Retrying in 10 seconds...")
                time.sleep(10)  # add a longer delay before retrying
                retries += 1
            else:
                raise
#(("relationshipB", rdflib.OWL.Class),
#("ClassD", rdflib.OWL.DatatypeProperty),
#("attributeD", rdflib.OWL.ObjectProperty)):

uri_dict={}
edge = URIRef(n + "in_country")
cnt=URIRef(n + "countries")
stts=URIRef(n + "states")
Cname=URIRef(n + "has_name")
Sname=URIRef(n + "has_name")

g.add((edge, RDF.type,OWL.ObjectProperty))
g.add((Cname, RDF.type,OWL.DatatypeProperty))
g.add((Sname, RDF.type,OWL.DatatypeProperty))



# Modify the loop to use the search_entity() function
for index, row in country.iterrows():
    print(row["state"])
    State = row["state"]
    Country = row["country"]
    if Country not in uri_dict:
        uri_dict[Country] = search_entity(Country)
    if State not in uri_dict:
        uri_dict[State] = search_entity(State)
        if uri_dict[State] is None:
          uri_dict[State]=URIRef(n +"states/"+ urllib.parse.quote(row["state"]))
        print(uri_dict[State])

    if uri_dict[Country] is not None:
        target_uri = URIRef(uri_dict[Country])
        if uri_dict[State] is not None:
            print("+")
            source_uri = URIRef(uri_dict[State])


            g.add((target_uri,RDF.type,cnt))
            g.add((source_uri,RDF.type,stts))
            g.add((source_uri, edge, target_uri))

            g.add((target_uri,Cname,Literal(Country, datatype=XSD.string)))
            g.add((source_uri,Sname,Literal(State, datatype=XSD.string)))
# Out:
# OR
# http://dbpedia.org/resource/OR
# +
# Brentwood
# http://dbpedia.org/resource/Category:Brentwood
# +
# Los Feliz
# http://dbpedia.org/resource/Los_Feliz
# +
# TX
# http://dbpedia.org/resource/TX
# +
# MA
# http://dbpedia.org/resource/MA
# +
# UT
# http://dbpedia.org/property/ut
# +
# Ontario Street
# http://dbpedia.org/resource/Ontario_Street
# +
# PA
# http://dbpedia.org/resource/PA
# +
# CA
# http://dbpedia.org/resource/CA
# +
# WI
# http://dbpedia.org/property/wi
# +
# DE
# http://dbpedia.org/resource/DE
# +
# SC
# http://dbpedia.org/resource/SC
# +
# MO
# http://dbpedia.org/resource/MO
# +
# NV
# http://dbpedia.org/resource/NV
# +
# WA
# http://dbpedia.org/property/wa
# +
# Weirs Beach
# http://dbpedia.org/resource/Weirs_Beach
# +
# NE
# http://dbpedia.org/resource/NE
# +
# IL
# http://dbpedia.org/resource/IL
# +
# CO
# http://dbpedia.org/resource/CO
# +
# MD
# http://dbpedia.org/resource/MD
# +
# Lawrenceville
# http://dbpedia.org/resource/Lawrenceville
# +
# Crestview Heights
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Crestview%20Heights
# +
# MS
# http://dbpedia.org/resource/MS
# +
# CT
# http://dbpedia.org/resource/CT
# +
# FL
# http://dbpedia.org/resource/FL
# +
# Mount Ross
# http://dbpedia.org/resource/Mount_Ross
# +
# Murdock
# http://dbpedia.org/resource/Murdock
# +
# NY
# http://dbpedia.org/resource/NY
# +
# Hassan
# http://dbpedia.org/resource/Hassan
# +
# City Of Spokane Valley
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/City%20Of%20Spokane%20Valley
# +
# KS
# http://dbpedia.org/resource/KS
# +
# Grove
# http://dbpedia.org/resource/Grove
# +
# WV
# http://dbpedia.org/property/wv
# +
# AK
# http://dbpedia.org/resource/AK
# +
# GA
# http://dbpedia.org/resource/GA
# +
# No Providence
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/No%20Providence
# +
# AZ
# http://dbpedia.org/resource/AZ
# +
# MN
# http://dbpedia.org/resource/MN
# +
# NJ
# http://dbpedia.org/resource/NJ
# +
# MI
# http://dbpedia.org/resource/MI
# +
# Quincy Center
# http://dbpedia.org/resource/Quincy_Center
# +
# IN
# http://dbpedia.org/resource/IN
# +
# LA
# http://dbpedia.org/resource/LA
# +
# OH
# http://dbpedia.org/resource/OH
# +
# Village Of Wellington
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Village%20Of%20Wellington
# +
# Marble Cliff
# http://dbpedia.org/resource/Marble_Cliff
# +
# VA
# http://dbpedia.org/resource/VA
# +
# Midtown
# http://dbpedia.org/resource/Midtown
# +
# TN
# http://dbpedia.org/resource/TN
# +
# Oldtown
# http://dbpedia.org/resource/Oldtown
# +
# Mphs
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Mphs
# +
# Elmhurst
# http://dbpedia.org/resource/Elmhurst
# +
# New York City
# http://dbpedia.org/resource/Category:New_York_City
# +
# Manhattan
# http://dbpedia.org/resource/Category:Manhattan
# +
# ME
# http://dbpedia.org/resource/ME
# +
# Queens
# http://dbpedia.org/resource/Queens
# +
# S Connelsvl
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/S%20Connelsvl
# +
# Juanita
# http://dbpedia.org/resource/Juanita
# +
# Forest View
# http://dbpedia.org/resource/Forest_View
# +
# IA
# http://dbpedia.org/resource/IA
# +
# Kingsgate
# http://dbpedia.org/resource/Kingsgate
# +
# Mount Laurel Township
# http://dbpedia.org/resource/Mount_Laurel_Township
# +
# St Albans
# http://dbpedia.org/resource/Category:St_Albans
# +
# Queensgate
# http://dbpedia.org/resource/Queensgate
# +
# Pitt
# http://dbpedia.org/resource/Pitt
# +
# Raugust
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Raugust
# +
# Nyc
# http://dbpedia.org/resource/Nyc
# +
# Fairmont
# http://dbpedia.org/resource/Fairmont
# +
# Blue Anchor
# http://dbpedia.org/resource/Blue_Anchor
# +
# Uptown
# http://dbpedia.org/resource/Uptown
# +
# Longview
# http://dbpedia.org/resource/Longview
# +
# DC
# http://dbpedia.org/resource/DC
# +
# Phila
# http://dbpedia.org/resource/Phila
# +
# Matthewstown
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Matthewstown
# +
# RI
# http://dbpedia.org/resource/RI
# +
# KY
# http://dbpedia.org/resource/KY
# +
# Seacliff
# http://dbpedia.org/resource/Seacliff
# +
# Country Life Acres
# http://dbpedia.org/resource/Country_Life_Acres
# +
# NC
# http://dbpedia.org/resource/NC
# +
# Edmund
# http://dbpedia.org/resource/Edmund
# +
# OK
# http://dbpedia.org/resource/OK
# +
# NM
# http://dbpedia.org/resource/NM
# +
# N Egremont
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/N%20Egremont
# +
# Elnora
# http://dbpedia.org/resource/Elnora
# +
# Bicentennial
# http://dbpedia.org/resource/Bicentennial
# +
# Richmond Highlands
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Richmond%20Highlands
# +
# Brownsboro Farm
# http://dbpedia.org/resource/Brownsboro_Farm
# +
# Htfd
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Htfd
# +
# No Bethesda
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/No%20Bethesda
# +
# Glendale
# http://dbpedia.org/resource/Category:Glendale
# +
# Bloomington Hills
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Bloomington%20Hills
# +
# Oella
# http://dbpedia.org/resource/Oella
# +
# Hono
# http://dbpedia.org/resource/Hono
# +
# Murfreesbr
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Murfreesbr
# +
# Wm Penn Anx W
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Wm%20Penn%20Anx%20W
# +
# Fort Dearborn
# http://dbpedia.org/resource/Fort_Dearborn
# +
# West Medford
# http://dbpedia.org/resource/West_Medford
# +
# Deephaven
# http://dbpedia.org/resource/Deephaven
# +
# Saint Davids
# http://dbpedia.org/resource/Saint_Davids
# +
# South Bowie
# http://dbpedia.org/resource/South_Bowie
# +
# Bengal
# http://dbpedia.org/resource/Bengal
# +
# Wesley Chapel
# http://dbpedia.org/resource/Wesley_Chapel
# +
# Fort Devens
# http://dbpedia.org/resource/Fort_Devens
# +
# Burlngtn City
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Burlngtn%20City
# +
# Colorado Spgs
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Colorado%20Spgs
# +
# Willoughby Hills
# http://dbpedia.org/resource/Willoughby_Hills
# +
# Miami
# http://dbpedia.org/resource/Category:Miami
# +
# West Glenville
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/West%20Glenville
# +
# Hanes
# http://dbpedia.org/resource/Hanes
# +
# Mozart
# http://dbpedia.org/resource/Mozart
# +
# Hollywood Park
# http://dbpedia.org/resource/Category:Hollywood_Park
# +
# MT
# http://dbpedia.org/property/mt
# +
# Carpolis
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Carpolis
# +
# Bonney Lk
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Bonney%20Lk
# +
# West Mifflin
# http://dbpedia.org/resource/West_Mifflin
# +
# AR
# http://dbpedia.org/resource/AR
# +
# Nlr
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Nlr
# +
# Wapping
# http://dbpedia.org/resource/Wapping
# +
# Pleasantdale
# http://dbpedia.org/resource/Pleasantdale
# +
# Washington Township
# http://dbpedia.org/resource/Washington_Township
# +
# Pamrapo
# http://dbpedia.org/resource/Pamrapo
# +
# Ssf
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Ssf
# +
# Pls Vrds Est
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Pls%20Vrds%20Est
# +
# Olivenhain
# http://dbpedia.org/resource/Olivenhain
# +
# La Conchita
# http://dbpedia.org/resource/La_Conchita
# +
# Durlach
# http://dbpedia.org/resource/Durlach
# +
# Echelon
# http://dbpedia.org/resource/Echelon
# +
# Wla
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Wla
# +
# Saint Pete Beach
# http://dbpedia.org/resource/Saint_Pete_Beach
# +
# Sheffield Village
# http://www.wikidata.org/entity/Q1984238
# +
# Randallsville
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Randallsville
# +
# Cresthill
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Cresthill
# +
# North White Plains
# http://dbpedia.org/resource/North_White_Plains
# +
# City Of Wb
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/City%20Of%20Wb
# +
# Islip Manor
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Islip%20Manor
# +
# Guilford Courthouse National
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Guilford%20Courthouse%20National
# +
# Mormon Island
# http://dbpedia.org/resource/Mormon_Island
# +
# Village Of Mastic Beach
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Village%20Of%20Mastic%20Beach
# +
# ND
# http://dbpedia.org/resource/ND
# +
# Williams Crk
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Williams%20Crk
# +
# Vlg Of 4 Ssns
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Vlg%20Of%204%20Ssns
# +
# Brownstown Twp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Brownstown%20Twp
# +
# Evesham Twp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Evesham%20Twp
# +
# Riverton
# http://dbpedia.org/resource/Riverton
# +
# Park Hills
# http://dbpedia.org/resource/Park_Hills
# +
# Ny
# http://dbpedia.org/resource/Ny
# +
# West Vail
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/West%20Vail
# +
# Cimarron Hills
# http://dbpedia.org/resource/Cimarron_Hills
# +
# G P O
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/G%20P%20O
# +
# West Pittsburg
# http://dbpedia.org/resource/West_Pittsburg
# +
# Ruscombmanor Twp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Ruscombmanor%20Twp
# +
# Gloucester City
# http://dbpedia.org/resource/Gloucester_City
# +
# South St Paul
# http://dbpedia.org/resource/South_St_Paul
# +
# Wedgwood
# http://dbpedia.org/resource/Wedgwood
# +
# Alt De Berwind
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Alt%20De%20Berwind
# +
# North Redington Beach
# http://dbpedia.org/resource/North_Redington_Beach
# +
# Syr
# http://dbpedia.org/resource/Syr
# +
# AL
# http://dbpedia.org/resource/AL
# +
# So Portland
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/So%20Portland
# +
# Manor Ridge
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Manor%20Ridge
# +
# Fmy
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Fmy
# +
# Camden
# http://dbpedia.org/resource/Category:Camden
# +
# Arnold
# http://dbpedia.org/resource/Arnold
# +
# San Marin
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/San%20Marin
# +
# Chevy Chs Vlg
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Chevy%20Chs%20Vlg
# +
# Howard
# http://dbpedia.org/resource/Howard
# +
# Bellefonte
# http://dbpedia.org/resource/Bellefonte
# +
# ID
# http://dbpedia.org/resource/ID
# +
# Gilgo Beach
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Gilgo%20Beach
# +
# Talladega Springs
# http://dbpedia.org/resource/Talladega_Springs
# +
# Rockville
# http://dbpedia.org/resource/Category:Rockville
# +
# Clarkson Valley
# http://dbpedia.org/resource/Clarkson_Valley
# +
# Lake Mahopac
# http://dbpedia.org/resource/Lake_Mahopac
# +
# Sunrise
# http://dbpedia.org/property/sunrise
# +
# Hamilton Twp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Hamilton%20Twp
# +
# N Haven
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/N%20Haven
# +
# Clover Bottom
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Clover%20Bottom
# +
# NH
# http://dbpedia.org/resource/NH
# +
# Manhattanville
# http://dbpedia.org/resource/Manhattanville
# +
# Bloomington Heights
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Bloomington%20Heights
# +
# Rivervale
# http://dbpedia.org/resource/Rivervale
# +
# No Natick
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/No%20Natick
# +
# Radburn
# http://dbpedia.org/resource/Radburn
# +
# Fayson Lakes
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Fayson%20Lakes
# +
# Brandtsville
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Brandtsville
# +
# Derry Church
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Derry%20Church
# +
# Oak Park Hts
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Oak%20Park%20Hts
# +
# Paradise Park
# http://dbpedia.org/resource/Paradise_Park
# +
# Townley
# http://dbpedia.org/resource/Townley
# +
# Hbg Inter Airp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Hbg%20Inter%20Airp
# +
# Naples
# http://dbpedia.org/resource/Category:Naples
# +
# Larimers Corner
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Larimers%20Corner
# +
# Woodbury
# http://dbpedia.org/resource/Woodbury
# +
# Queen City
# http://dbpedia.org/resource/Queen_City
# +
# Rockville Center
# http://dbpedia.org/resource/Rockville_Center
# +
# Prt Jefferson
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Prt%20Jefferson
# +
# Camroden
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Camroden
# +
# Harristown
# http://dbpedia.org/resource/Harristown
# +
# Arco-plaza
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Arco-plaza
# +
# Jackson Hole
# http://dbpedia.org/resource/Jackson_Hole
# +
# Fox Rv Vly Gn
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Fox%20Rv%20Vly%20Gn
# +
# Ft Lauderdale
# http://dbpedia.org/resource/Ft_Lauderdale
# +
# SD
# http://dbpedia.org/resource/SD
# +
# Bouquet Canyon
# http://dbpedia.org/resource/Bouquet_Canyon
# +
# Santa Venetia
# http://dbpedia.org/resource/Santa_Venetia
# +
# Salt Lake Cty
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Salt%20Lake%20Cty
# +
# Darrtown
# http://dbpedia.org/resource/Darrtown
# +
# Drexelbrook
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Drexelbrook
# +
# Wilm
# http://dbpedia.org/resource/Wilm
# +
# Wankers Corners
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Wankers%20Corners
# +
# Rahns
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Rahns
# +
# Cherry Hl Vlg
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Cherry%20Hl%20Vlg
# +
# Saint Andrews
# http://dbpedia.org/resource/Category:Saint_Andrews
# +
# Pleasant Valley
# http://dbpedia.org/resource/Pleasant_Valley
# +
# Ritz
# http://dbpedia.org/resource/Ritz
# +
# Cascade
# http://dbpedia.org/resource/Cascade
# +
# Atl
# http://dbpedia.org/resource/Atl
# +
# So Yarmouth
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/So%20Yarmouth
# +
# Wheatfield
# http://dbpedia.org/resource/Wheatfield
# +
# Holly Ridge
# http://dbpedia.org/resource/Holly_Ridge
# +
# Strawberry Point
# http://dbpedia.org/resource/Strawberry_Point
# +
# Bammel
# http://dbpedia.org/resource/Bammel
# +
# Sky Valley
# http://dbpedia.org/resource/Sky_Valley
# +
# Valley View
# http://dbpedia.org/resource/Valley_View
# +
# Fruitville
# http://dbpedia.org/resource/Fruitville
# +
# Fredon Twp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Fredon%20Twp
# +
# VT
# http://dbpedia.org/property/vt
# +
# Bamboo
# http://dbpedia.org/resource/Bamboo
# +
# Great Notch
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Great%20Notch
# +
# Saint Anne
# http://dbpedia.org/resource/Saint_Anne
# +
# Montville Township
# http://dbpedia.org/resource/Montville_Township
# +
# Norland Park
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Norland%20Park
# +
# Plantation
# http://dbpedia.org/resource/Plantation
# +
# Fire Island Pines
# http://dbpedia.org/resource/Fire_Island_Pines
# +
# Venetian Islands
# http://dbpedia.org/resource/Venetian_Islands
# +
# Baxter Estates
# http://dbpedia.org/resource/Baxter_Estates
# +
# Choconut Center
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Choconut%20Center
# +
# Riverchase
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Riverchase
# +
# Framingham So
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Framingham%20So
# +
# Deerfield Beach
# http://dbpedia.org/resource/Deerfield_Beach
# +
# Briarcliff Mnr
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Briarcliff%20Mnr
# +
# Mayfield Hts
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Mayfield%20Hts
# +
# Cherry Hill Township
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Cherry%20Hill%20Township
# +
# East Haven
# http://dbpedia.org/resource/East_Haven
# +
# HI
# http://dbpedia.org/resource/HI
# +
# Spuyten Duyvil
# http://dbpedia.org/resource/Spuyten_Duyvil
# +
# Magnolia
# http://dbpedia.org/resource/Category:Magnolia
# +
# Margate
# http://dbpedia.org/resource/Category:Margate
# +
# Bunker Hill Village
# http://dbpedia.org/resource/Bunker_Hill_Village
# +
# St Remy
# http://dbpedia.org/resource/St_Remy
# +
# Cushing
# http://dbpedia.org/resource/Cushing
# +
# West Fort Lee
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/West%20Fort%20Lee
# +
# Round Lake Heights
# http://dbpedia.org/resource/Round_Lake_Heights
# +
# Collings Lakes
# http://dbpedia.org/resource/Collings_Lakes
# +
# Huetter
# http://dbpedia.org/resource/Huetter
# +
# Deer Wells
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Deer%20Wells
# +
# Macomb Twp
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Macomb%20Twp
# +
# North Glenn
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/North%20Glenn
# +
# Chupadero
# http://dbpedia.org/resource/Chupadero
# +
# West Deerfield
# http://dbpedia.org/resource/West_Deerfield
# +
# Friendsville
# http://dbpedia.org/resource/Friendsville
# +
# East Htfd
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/East%20Htfd
# +
# Wilton Manors
# http://dbpedia.org/resource/Wilton_Manors
# +
# Groesbeck
# http://dbpedia.org/resource/Groesbeck
# +
# Weymouth Nas
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Weymouth%20Nas
# +
# Shawnee Mission
# http://dbpedia.org/resource/Shawnee_Mission
# +
# Bloomfld Hls
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Bloomfld%20Hls
# +
# Mckownville
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Mckownville
# +
# Joppatowne
# http://dbpedia.org/resource/Joppatowne
# +
# Co Spgs
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Co%20Spgs
# +
# Brownhelm
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Brownhelm
# +
# Togus
# http://dbpedia.org/resource/Togus
# +
# Malba
# http://dbpedia.org/resource/Malba
# +
# Dania Beach
# http://dbpedia.org/resource/Dania_Beach
# +
# Fair Haven
# http://dbpedia.org/resource/Fair_Haven
# +
# Seabrook Island
# http://dbpedia.org/resource/Seabrook_Island
# +
# Valleyview
# http://dbpedia.org/resource/Valleyview
# +
# Pembroke Pnes
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Pembroke%20Pnes
# +
# Palmer
# http://dbpedia.org/resource/Palmer
# +
# Honey Creek
# http://dbpedia.org/resource/Honey_Creek
# +
# Davidsburg
# http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Davidsburg
# +

# %%
state = df[['city', 'state']]

state = state.dropna()
state = state.drop_duplicates()

edge = URIRef(n + "in_state")
Ctname=URIRef(n + "has_name")
cty=URIRef(n + "city")

g.add((edge, RDF.type,OWL.ObjectProperty))
g.add((Ctname, RDF.type,OWL.DatatypeProperty))

# Modify the loop to use the search_entity() function
for index, row in state.iterrows():
    print(row["city"],'-',row["state"])
    City = row["city"]
    State = row["state"]
    if State not in uri_dict:
        uri_dict[State] = search_entity(State)
    if City not in uri_dict:
        uri_dict[City] = search_entity(City)
        if uri_dict[City] is None:
          uri_dict[City]=URIRef(n +"cities/"+ urllib.parse.quote(row["city"]))
    if uri_dict[State] is not None:
        target_uri = URIRef(uri_dict[State])
        if uri_dict[City] is not None:
            source_uri = URIRef(uri_dict[City])

            #     city      a       city
            g.add((source_uri,RDF.type,cty))
            #      city       city_state   state
            g.add((source_uri, edge, target_uri))


            #      city        name        name of city
            g.add((source_uri,Ctname,Literal(City, datatype=XSD.string)))
# Out:
# Bend - OR
# Los Angeles - Brentwood
# Los Angeles - Los Feliz
# Houston - TX
# Hyannis - MA
# Provo - UT
# Spring - TX
# Chicago - Ontario Street
# West Chester - PA
# San Jose - CA
# Menifee - CA
# Grand Prairie - TX
# Wausau - WI
# Wilmington - DE
# Pickens - SC
# Arnold - MO
# Tracy - CA
# Pasadena - TX
# Henderson - NV
# Kent - WA
# Laconia - Weirs Beach
# Southlake - TX
# College Station - TX
# Omaha - NE
# Addison - IL
# Arvada - CO
# Westminster - MD
# Hermosa Beach - CA
# Luzerne - PA
# Lawrence Township - Lawrenceville
# Saint Louis - MO
# Endicott - Crestview Heights
# Sturbridge - MA
# Cedar Park - TX
# Hernando - MS
# Fairfield - CT
# Gainesville - FL
# Pine Plains - Mount Ross
# Loveland - Murdock
# Staten Island - NY
# Osseo - Hassan
# Spokane - City Of Spokane Valley
# Santa Cruz - CA
# Olathe - KS
# Bloomfield - Grove
# Laguna Niguel - CA
# Newark - DE
# Barboursville - WV
# Fairbanks - AK
# Americus - GA
# Providence - No Providence
# Cockeysville - MD
# Urbana - IL
# Phoenix - AZ
# Minneapolis - MN
# Maitland - FL
# Shelton - CT
# Massapequa Park - NY
# Saddle Brook - NJ
# Philadelphia - PA
# Southaven - MS
# Essex - MD
# Redford - MI
# White Lake - MI
# Quincy - Quincy Center
# Indianapolis - IN
# Harvey - LA
# Denver - CO
# Rochester - MI
# Fort Smith - AR
# Harleysville - PA
# Fort Lauderdale - Dania Beach
# New Haven - Fair Haven
# Johns Island - Seabrook Island
# Columbus - Valleyview
# Hollywood - Pembroke Pnes
# Pennington - NJ
# Bossier City - LA
# Boise - ID
# Pearland - TX
# Crown Point - Palmer
# Jefferson City - Honey Creek
# Dover - Davidsburg
# Ashland - VA

# %%
city = df[['name', 'city']]
city = city.dropna()
city = city.drop_duplicates()

edge = URIRef(n + "in_city")
restuarant=URIRef(n+"restaurant")

g.add((edge, RDF.type,OWL.ObjectProperty))

# Modify the loop to use the search_entity() function
for index, row in city.iterrows():
    print(row["name"],'-',row["city"])
    City = row["city"]
    Name = row["name"]
    if City not in uri_dict:
        uri_dict[City] = search_entity(City)
    if uri_dict[City] is not None:
        target_uri = URIRef(uri_dict[City])
        source = URIRef(n +"restaurant/"+ urllib.parse.quote(Name))

        g.add((source,RDF.type, restuarant))

        g.add((source, edge, target_uri))
# Out:
# Little Pizza Paradise - Bend
# The Brentwood - Los Angeles
# Bravo Pizza Hollywood - Los Angeles
# Lucky's Pub - Houston
# Roadhouse Cafe - Hyannis
# Brigham Young University - Provo
# Luke's Locker - Spring
# Francesca's On Chestnut - Chicago
# Country Bagel Bakery - West Chester
# Buca Di Beppo - San Jose - Oakridge - San Jose
# Giovanni's Pizza and Pasta - Menifee
# Uncle John's Pizza - Grand Prairie
# Philly's Subs - Wausau
# Satsuma - Wilmington
# Gatehouse Restaurant - Pickens
# Imo's Pizza - Arnold
# Applebee's Tracy - Tracy
# Little Caesars Pizza - Pasadena
# Joey's N Y Pizza - Henderson
# Keyme - Kent
# Tower Hill Tavern - Laconia
# Brio Tuscan Grille - Southlake - Southlake Town Square - Southlake
# Doubledave's Pizza Works - College Station
# Frank's Pizzeria - Omaha
# Casino's Pizza - Addison
# Glutenfree Things - Arvada
# Mediterraneo Ristorante - Westminster
# Patrick Molloy's Sports Pub - Hermosa Beach
# Salerno's Pizza Restaurant - Luzerne
# Nino's Trattoria & Pizzeria - Lawrence Township
# Oceano Bistro - Clayton - Saint Louis
# Brothers 2 - Endicott
# Uno Pizzeria & Grill - Sturbridge - Sturbridge
# Doubledave's Pizzaworks - Cedar Park
# Buon Cibo - Hernando
# Tomato & Basil - Fairfield
# Blockbuster - Gainesville
# Stissing House - Pine Plains
# Larosa's Pizzeria - Loveland
# Mario's - Staten Island - Staten Island
# The Lookout Catering - Osseo
# Boston's Restaurant & Sports Bar - Spokane
# Ristorante Italiano - Santa Cruz
# Zios Italian Kitchen - Olathe - Olathe
# Town Pub - Bloomfield
# I Love Bagels - Laguna Niguel
# Ming Garden Cocktails Chinese Restaurant - Newark
# Tascali's Decades Pasta & Grill - Barboursville
# Chena's Alaskan Grill - Fairbanks
# La Hacienda - Americus
# West River Cafe - Providence
# Original Giorgio's - Cockeysville
# Casa-Rica - Westminster
# Crane Alley - Urbana
# Peter Piper Pizza - Phoenix
# Gina Maria's Pizza - Minneapolis
# Martinizing - Arvada
# Nypd Pizza - Maitland
# Carvalho's Brazilian Kitchen - Scottsdale
# Rosa Mexicano - New York
# The Pizza Parlor - Pearland
# Rick's Cabaret - Indianapolis
# Mighty Mick's Pub & Cafe - Crown Point
# Prison Brews Brewery & Restaurant - Jefferson City
# Moonlight Cafe - Dover
# Guidos - Ashland

# %%
from rdflib import Graph, Literal, RDF,RDFS, URIRef, Namespace #basic RDF handling
from rdflib.namespace import FOAF , XSD #most common namespaces
import urllib.parse #for parsing strings to URI's
#for index, row in df.iterrows():
#    g.add((URIRef(ppl+row['Name']), RDF.type, FOAF.Person))
#    g.add((URIRef(ppl+row['Name']), URIRef(schema+'name'), Literal(row['Name'], datatype=XSD.string) ))
#    g.add((URIRef(ppl+row['Name']), FOAF.age, Literal(row['Age'], datatype=XSD.integer) ))
#    g.add((URIRef(ppl+row['Name']), URIRef(schema+'address'), Literal(row['Address'], datatype=XSD.string) ))
#    g.add((URIRef(loc+urllib.parse.quote(row['Address'])), URIRef(schema+'name'), Literal(row['Address'], datatype=XSD.string) ))
item_description = df[['menu item', 'item description','name','pizza_type']]
price=df[[ 'menu item','item value','name','pizza_type']]
currency=df[[ 'name','currency','menu item','pizza_type']]

item_description=item_description.dropna()
item_description=item_description.drop_duplicates()
pizza_type=pizza_type.dropna()
pizza_type=pizza_type.drop_duplicates()
currency=currency.dropna()
currency=currency.drop_duplicates()
price=price.dropna()
price=price.drop_duplicates()
pizza=pizza.dropna()
pizza=pizza.drop_duplicates()
new_Categories=new_Categories.dropna()
new_Categories=new_Categories.drop_duplicates()
postcode=postcode.dropna()
postcode=postcode.drop_duplicates()
address=address.drop_duplicates()
n = Namespace('http://www.city.ac.uk/ds/inm713/hadi_ghasemi/')

edge = URIRef(n + "has_address")
Rname=URIRef(n + "has_name")

g.add((edge, RDF.type,OWL.DatatypeProperty))
g.add((Rname, RDF.type,OWL.DatatypeProperty))


for index, row in address.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    target = Literal(row["address"], datatype=XSD.string)
    name=Literal(row["name"], datatype=XSD.string)


    #      restu  addr   literal
    g.add((source,edge, target))
    #     rest    name    literal
    g.add((source,Rname, name))
    #     rest    type      restaurant

edge = URIRef(n + "has_post_code")

g.add((edge, RDF.type,OWL.DatatypeProperty))

for index, row in postcode.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    target = Literal(row["postcode"], datatype=XSD.string)

    #       rest post   literal
    g.add((source,edge, target))

edge = URIRef(n + "restaurant_type")

g.add((edge, RDF.type,OWL.ObjectProperty))
Category=URIRef(n+"store")
for index, row in new_Categories.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    target = URIRef(n +"restaurant_types/"+ urllib.parse.quote(row["category"]))
    label = Literal(row["category"], datatype=XSD.string)
    g.add((target,RDFS.label , label))
    #      category  type   caregory
    g.add((target,RDFS.subClassOf , Category))
    #      rest   catg   category
    g.add((source,RDF.type, target))

edge = URIRef(n + "has_item")
Pname=URIRef(n + "has_name")
Pizza=URIRef(n+"food/pizza")
Food=URIRef(n+"food")
g.add((Pizza, RDFS.subClassOf,Food))

g.add((edge, RDF.type,OWL.ObjectProperty))
g.add((Pname, RDF.type,OWL.DatatypeProperty))
edge1 =RDF.type# URIRef(n + "pizza_type")
pizza_types=URIRef(n+"pizza_types")
g.add((edge1, RDF.type,OWL.ObjectProperty))

for index, row in pizza.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    pizz = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    types=URIRef(n +"pizza_types/" +urllib.parse.quote(row["pizza_type"]) )
    label=Literal(row["pizza_type"], datatype=XSD.string)
    #     piza_type type  pizza_types
    g.add((types,RDFS.subClassOf, Pizza))
    g.add((types,RDFS.label, label))
    #      pizza   type  pizza_type
    g.add((pizz,edge1, types))
    name=Literal(row["menu item"], datatype=XSD.string)

    #     pizza   type   pizza
    #g.add((pizz,RDF.type, Pizza))
    #     rest    menu    pizza
    g.add((source,edge, pizz))
    #     pizza   name   literal
    g.add((pizz,Pname, name))

#done#############################################################################################

edge = URIRef(n + "has_price")

g.add((edge, RDF.type,OWL.DatatypeProperty))

for index, row in price.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    target = Literal(row["item value"], datatype=XSD.float)

    #     pizza   price   value
    g.add((source,edge, target))

edge = URIRef(n + "has_currency")

g.add((edge, RDF.type,OWL.DatatypeProperty))


for index, row in currency.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    #target = URIRef(n +"currency/"+ row["currency"])
    target = Literal(row["currency"], datatype=XSD.string)
    #      pizza   currency  value
    g.add((source,edge, target))

   ###############################################################



#for index, row in pizza_type.iterrows():
    # add triple to rdf-graph
    #source = URIRef(n +"food/"+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    #target = URIRef(n +"pizza_type/" +urllib.parse.quote(row["pizza_type"]) )

    #     piza_type type  pizza_types
    #g.add((target,RDF.type, pizza_types))
    #      pizza   type  pizza_type
    #g.add((source,edge, target))
    #print(target)


edge = URIRef(n + "has_description")

g.add((edge, RDF.type,OWL.DatatypeProperty))


for index, row in item_description.iterrows():
    # add triple to rdf-graph
    source = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    target = Literal(row["item description"], datatype=XSD.string)

    #      pizza   desc   description
    g.add((source,edge, target))
#print(g.serialize(format='turtle'))
##done

# %%
g.serialize(destination='/content/output.owl', format='xml')
g.serialize(destination='/content/output1.ttl', format='turtle')
g.serialize(destination='/content/RDF.ttl', format='turtle')
# Out:
# <Graph identifier=Nce867578b65843c38430cf6d51c204c1 (<class 'rdflib.graph.Graph'>)>

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery

# Create an RDF graph
#g = Graph()
#g.parse("/content/output.ttl", format="turtle")

# Define the SPARQL query
sparql_query = """
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?stateName ?state ?city ?cityName (COUNT(?restaurant) AS ?restaurantCount)
WHERE {
  # ?restaurant rdf:type n:restaurant ;
              n:has_address ?address ;
              n:in_city ?city .
  # ?city n:in_state ?state .
  # ?state n:has_name ?stateName .
  # ?city n:has_name ?cityName .
}
GROUP BY ?state ?city ?stateName ?cityName
ORDER BY ?state ?restaurantCount
"""

# Prepare the query
query = prepareQuery(sparql_query)

# Execute the query on the graph
results = g.query(query)

# Create an empty DataFrame
df = pd.DataFrame(columns=["State", "City", "Restaurant Count","city_uri","state_uri"])

# Iterate over the results and add them to the DataFrame
for row in results:
    state = row["stateName"]
    city = row["cityName"]
    count = row["restaurantCount"]
    city_uri=row["city"]
    state_uri=row["state"]
    #print(f"State: {state}, City: {city}, Restaurant Count: {count}")

    df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)

# Print the DataFrame
df
# Out:
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
# <ipython-input-85-7a82de1fc3a2>:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"State": state, "City": city, "Restaurant Count": count,"city_uri":city_uri,"state_uri":state_uri}, ignore_index=True)
#                  State             City Restaurant Count  \
# 0                   MT         Billings                1
# 1                   MT          Bozeman                1
# 2                   MT         Missoula                3
# 3              Sunrise  Fort Lauderdale                8
# 4                   UT            Provo                1
# ..                 ...              ...              ...
# 767       Weymouth Nas   South Weymouth                1
# 768       Williams Crk     Indianapolis                5
# 769                Wla      Los Angeles                8
# 770      Wm Penn Anx W     Philadelphia               15
# 771  Sheffield Village           Elyria                1
#
#                                               city_uri  \
# 0                 http://dbpedia.org/resource/Billings
# 1                  http://dbpedia.org/resource/Bozeman
# 2                 http://dbpedia.org/resource/Missoula
# 3          http://dbpedia.org/resource/Fort_Lauderdale
# 4                    http://dbpedia.org/resource/Provo
# ..                                                 ...
# 767         http://dbpedia.org/resource/South_Weymouth
# 768  http://dbpedia.org/resource/Category:Indianapolis
# 769            http://dbpedia.org/resource/Los_Angeles
# 770  http://dbpedia.org/resource/Category:Philadelphia
# 771                 http://dbpedia.org/resource/Elyria
#
#                                              state_uri
# 0                       http://dbpedia.org/property/mt
# 1                       http://dbpedia.org/property/mt
# 2                       http://dbpedia.org/property/mt
# 3                  http://dbpedia.org/property/sunrise
# 4                       http://dbpedia.org/property/ut
# ..                                                 ...
# 767  http://www.city.ac.uk/ds/inm713/hadi_ghasemi/s...
# 768  http://www.city.ac.uk/ds/inm713/hadi_ghasemi/s...
# 769  http://www.city.ac.uk/ds/inm713/hadi_ghasemi/s...
# 770  http://www.city.ac.uk/ds/inm713/hadi_ghasemi/s...
# 771            http://www.wikidata.org/entity/Q1984238
#
# [772 rows x 5 columns]

# %%
df.head(20)
# Out:
#       State             City Restaurant Count  \
# 0        MT         Billings                1
# 1        MT          Bozeman                1
# 2        MT         Missoula                3
# 3   Sunrise  Fort Lauderdale                8
# 4        UT            Provo                1
# 5        UT         Gunnison                1
# 6        UT           Layton                2
# 7        UT       Cedar City                9
# 8        VT        Williston                1
# 9        WA          Langley                1
# 10       WA      Federal Way                1
# 11       WA           Lynden                1
# 12       WA        Vancouver                1
# 13       WA       Marysville                1
# 14       WA          Olympia                1
# 15       WA         Bellevue                1
# 16       WA          Pullman                2
# 17       WA             Kent                3
# 18       WA           Auburn                3
# 19       WA           Tacoma                5
#
#                                         city_uri  \
# 0           http://dbpedia.org/resource/Billings
# 1            http://dbpedia.org/resource/Bozeman
# 2           http://dbpedia.org/resource/Missoula
# 3    http://dbpedia.org/resource/Fort_Lauderdale
# 4              http://dbpedia.org/resource/Provo
# 5           http://dbpedia.org/resource/Gunnison
# 6             http://dbpedia.org/resource/Layton
# 7         http://dbpedia.org/resource/Cedar_City
# 8          http://dbpedia.org/resource/Williston
# 9   http://dbpedia.org/resource/Category:Langley
# 10       http://dbpedia.org/resource/Federal_Way
# 11            http://dbpedia.org/resource/Lynden
# 12         http://dbpedia.org/resource/Vancouver
# 13        http://dbpedia.org/resource/Marysville
# 14           http://dbpedia.org/resource/Olympia
# 15          http://dbpedia.org/resource/Bellevue
# 16           http://dbpedia.org/resource/Pullman
# 17     http://dbpedia.org/resource/Category:Kent
# 18            http://dbpedia.org/resource/Auburn
# 19            http://dbpedia.org/property/tacoma
#
#                               state_uri
# 0        http://dbpedia.org/property/mt
# 1        http://dbpedia.org/property/mt
# 2        http://dbpedia.org/property/mt
# 3   http://dbpedia.org/property/sunrise
# 4        http://dbpedia.org/property/ut
# 5        http://dbpedia.org/property/ut
# 6        http://dbpedia.org/property/ut
# 7        http://dbpedia.org/property/ut
# 8        http://dbpedia.org/property/vt
# 9        http://dbpedia.org/property/wa
# 10       http://dbpedia.org/property/wa
# 11       http://dbpedia.org/property/wa
# 12       http://dbpedia.org/property/wa
# 13       http://dbpedia.org/property/wa
# 14       http://dbpedia.org/property/wa
# 15       http://dbpedia.org/property/wa
# 16       http://dbpedia.org/property/wa
# 17       http://dbpedia.org/property/wa
# 18       http://dbpedia.org/property/wa
# 19       http://dbpedia.org/property/wa

# %%
from rdflib import Graph, Literal
from rdflib.plugins.sparql import prepareQuery

# Create an RDF graph
#g = Graph()
#g.parse("/content/output1.ttl", format="turtle")

# Define the SPARQL query
sparql_query = """
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT  ?name
WHERE {
  # ?restaurant rdf:type n:restaurant ;
              n:has_address ?address ;
              n:has_name ?name .
  OPTIONAL {
    # ?restaurant n:has_post_code ?postcode .
  }
  FILTER (!bound(?postcode))
}
"""

# Prepare the query
query = prepareQuery(sparql_query)

# Execute the query on the graph
results = g.query(query)
i=1
# Print the results
for row in results:
    name=row["name"]
    #restaurant = row["restaurant"]
    print(f"Restaurant {i}: {name}")
    i+=1
# Out:
# Restaurant 1: Sir Pizza
# Restaurant 2: Baldinelli Pizza
# Restaurant 3: Valley Lahvosh Baking
# Restaurant 4: Milt's Pizza Place Llc
# Restaurant 5: Masago
# Restaurant 6: Pizza City
# Restaurant 7: Villa Rose Pizza
# Restaurant 8: Ak Diamonds
# Restaurant 9: Two Brothers Deli
# Restaurant 10: Five Below
# Restaurant 11: San Biagio's Pizza

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery

# Create an RDF graph
#g = Graph()
#g.parse("/content/output.ttl", format="turtle")

# Define the SPARQL query
sparql_query = """
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX pt: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/>

SELECT (AVG(?price) AS ?averagePrice)
WHERE {
  # ?pizza rdf:type pt:margherita;
  n:has_price ?price .
}
"""

# Prepare the query
query = prepareQuery(sparql_query)

# Execute the query on the graph
results = g.query(query)
#         e:pizza_type n:pizza_types/margherita ;

# Print the results
for row in results:
    average_price = row["averagePrice"]
    average_price = float(average_price)
    print(f"Average Price: {average_price:.2f} USD")
# Out:
# Average Price: 15.54 USD

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery

# Create an RDF graph
#g = Graph()
#g.parse("/content/output.ttl", format="turtle")

# Define the SPARQL query
sparql_query = """
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX pt: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/>

SELECT ?restaurant ?name ?address ?rsname ?city ?cityname ?state ?statename ?country ?countryname ?postcode
WHERE {
  # ?restaurant rdf:type n:restaurant ;
              n:in_city ?city ;
              n:has_address ?address;
              n:has_name ?rsname;
              n:has_post_code ?postcode .
  # ?city n:has_name ?cityname;
        n:in_state ?state .
  # ?state n:has_name ?statename ;
         n:in_country ?country .
  # ?country n:has_name ?countryname.

  # ?restaurant n:has_item ?menu .
  # ?menu rdf:type pt:bianca .
}
"""

# Prepare the query
query = prepareQuery(sparql_query)

# Execute the query on the graph
results = g.query(query)

# Print the results
for row in results:
    restaurant = row["restaurant"]
    city = row["city"]
    cityname = row["cityname"]
    state=row["state"]
    statename=row["statename"]
    country=row["country"]
    countryname=row["countryname"]
    name = row["rsname"]
    address = row["address"]
    postcode=row["postcode"]
    print(f"Restaurant: {restaurant}")
    print(f"Name: {name}")
    print(f"City: {city}")
    print(f"City Name: {cityname}")
    print(f"State: {state}")
    print(f"State Name: {statename}")
    print(f"Country: {country}")
    print(f"Country Name: {countryname}")
    print(f"Address: {address}")
    print(f"Post Code: {postcode}")
    print()
# Out:
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Little%20Pizza%20Paradise
# Name: Little Pizza Paradise
# City: http://dbpedia.org/resource/Bend
# City Name: Bend
# State: http://dbpedia.org/resource/OR
# State Name: OR
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: Cascade Village Mall Across From Target
# Post Code: 97701
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Broad%20Street%20Cafe
# Name: Broad Street Cafe
# City: http://dbpedia.org/resource/Newark
# City Name: Newark
# State: http://dbpedia.org/resource/DE
# State Name: DE
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 562 Broad St
# Post Code: 7102
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Broad%20Street%20Cafe
# Name: Broad Street Cafe
# City: http://dbpedia.org/resource/Newark
# City Name: Newark
# State: http://dbpedia.org/resource/OH
# State Name: OH
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 562 Broad St
# Post Code: 7102
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Broad%20Street%20Cafe
# Name: Broad Street Cafe
# City: http://dbpedia.org/resource/Newark
# City Name: Newark
# State: http://dbpedia.org/resource/Midtown
# State Name: Midtown
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 562 Broad St
# Post Code: 7102
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Ciao%20Bella
# Name: Ciao Bella
# City: http://dbpedia.org/resource/Schererville
# City Name: Schererville
# State: http://dbpedia.org/resource/IN
# State Name: IN
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 1514 Us 41
# Post Code: 46375
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Verdile%27s
# Name: Verdile's
# City: http://dbpedia.org/resource/Category:Troy
# City Name: Troy
# State: http://dbpedia.org/resource/Pleasantdale
# State Name: Pleasantdale
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 572 2nd Ave
# Post Code: 12182
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Tutti%20Gusti
# Name: Tutti Gusti
# City: http://dbpedia.org/resource/Harrisonburg
# City Name: Harrisonburg
# State: http://dbpedia.org/resource/VA
# State Name: VA
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: Harrisonburg Va
# Post Code: 22801
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Jerry%27s%20Pizza%20%26%20Subs
# Name: Jerry's Pizza & Subs
# City: http://dbpedia.org/resource/Altamonte_Springs
# City Name: Altamonte Springs
# State: http://dbpedia.org/resource/FL
# State Name: FL
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 924 W 436
# Post Code: 32714
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/North%20End%20Pizzeria
# Name: North End Pizzeria
# City: http://dbpedia.org/resource/Los_Angeles
# City Name: Los Angeles
# State: http://dbpedia.org/resource/Category:Brentwood
# State Name: Brentwood
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 11628 Santa Monica Blvd
# Post Code: 90025
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/North%20End%20Pizzeria
# Name: North End Pizzeria
# City: http://dbpedia.org/resource/Los_Angeles
# City Name: Los Angeles
# State: http://dbpedia.org/resource/Los_Feliz
# State Name: Los Feliz
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 11628 Santa Monica Blvd
# Post Code: 90025
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/North%20End%20Pizzeria
# Name: North End Pizzeria
# City: http://dbpedia.org/resource/Los_Angeles
# City Name: Los Angeles
# State: http://dbpedia.org/resource/Bicentennial
# State Name: Bicentennial
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 11628 Santa Monica Blvd
# Post Code: 90025
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/North%20End%20Pizzeria
# Name: North End Pizzeria
# City: http://dbpedia.org/resource/Los_Angeles
# City Name: Los Angeles
# State: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Wla
# State Name: Wla
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 11628 Santa Monica Blvd
# Post Code: 90025
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/North%20End%20Pizzeria
# Name: North End Pizzeria
# City: http://dbpedia.org/resource/Los_Angeles
# City Name: Los Angeles
# State: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Arco-plaza
# State Name: Arco-plaza
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 11628 Santa Monica Blvd
# Post Code: 90025
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/North%20End%20Pizzeria
# Name: North End Pizzeria
# City: http://dbpedia.org/resource/Los_Angeles
# City Name: Los Angeles
# State: http://dbpedia.org/resource/CA
# State Name: CA
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 11628 Santa Monica Blvd
# Post Code: 90025
#
# Restaurant: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Positano%20-%20Greensboro
# Name: Positano - Greensboro
# City: http://dbpedia.org/resource/Greensboro
# City Name: Greensboro
# State: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/states/Guilford%20Courthouse%20National
# State Name: Guilford Courthouse National
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address:
http://www.city.ac.uk/ds/inm713/hadi_ghasemi/restaurant/Famous%20Famiglia
# Name: Famous Famiglia
# City: http://dbpedia.org/resource/New_York
# City Name: New York
# State: http://dbpedia.org/resource/NY
# State Name: NY
# Country: http://dbpedia.org/resource/US
# Country Name: US
# Address: 757 Broadway
# Post Code: 10003

# %%
import csv

csv_file = "/content/results.csv"

# Write the results to the CSV file
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Restaurant", "Name", "Address", "Postcode","cityname","statename","countryname", "City", "State", "Country"])  # Write the header
    for row in results:
        restaurant = row["restaurant"]
        name = row["rsname"]
        address = row["address"]
        postcode = row["postcode"]
        city = row["city"]
        state = row["state"]
        country = row["country"]

        cityname = row["cityname"]
        statename=row["statename"]
        countryname=row["countryname"]
        writer.writerow([restaurant, name, address, postcode,cityname,statename,countryname, city, state, country])

print("Results exported successfully to", csv_file)
# Out:
# Results exported successfully to /content/results.csv

# %%
# !pip install rdflib owlready2
# Out:
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 4.1 MB/s eta 0:00:00
# Collecting owlready2
#   Downloading owlready2-0.44.tar.gz (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 24.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.44-cp310-cp310-linux_x86_64.whl size=24078642 sha256=469add9637b8fcee2d6c84f5fdd33dc653b47c2e40af07c666de65dee616d4c5
#   Stored in directory: /root/.cache/pip/wheels/88/e1/04/583b0743b2907f091204baaa0aef9740f5ba5f3d2f6a5aa00d
# Successfully built owlready2
# Installing collected packages: owlready2, isodate, rdflib
# Successfully installed isodate-0.6.1 owlready2-0.44 rdflib-7.0.0

# %%
from owlready2 import *
onto_path.append("/content/")
onto = get_ontology("/content/RDF.owl").load()
#onto.load()
onto.base_iri = "http://www.city.ac.uk/ds/inm713/hadi_ghasemi/"

sync_reasoner([onto])
onto.save(file = 'Extended_RDF.owl', format = 'rdfxml')

onto.save(file = "Extended_RDF1", format = "ntriples")
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /usr/local/lib/python3.10/dist-packages/owlready2/hermit:/usr/local/lib/python3.10/dist-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmp4b54pc2h
# * Owlready2 * HermiT took 12.588951110839844 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
with onto:
  sync_reasoner()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /usr/local/lib/python3.10/dist-packages/owlready2/hermit:/usr/local/lib/python3.10/dist-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpawamowea
# * Owlready2 * HermiT took 15.38227391242981 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %% [markdown]
# # task 5

# %%
from rdflib import Graph, URIRef, Literal, OWL
from rdflib.plugins.sparql import prepareQuery

# Create an RDF graph
g = Graph()
g.parse("/content/RDF.owl", format="xml")
G=Graph()
G.parse("https://protege.stanford.edu/ontologies/pizza/pizza.owl", format="xml")
B=Graph()
B.parse("/content/RDF.owl", format="xml")
B.parse("https://protege.stanford.edu/ontologies/pizza/pizza.owl", format="xml")
equivalent_properties=[]
equivalences = [
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Country', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/countries'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/food/pizza'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Food', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/food'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/margherita'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/mushroom'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/sicilian'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/cheese'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/meat'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/italian'),
    ('http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizza', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/veggie')

]
for class1, class2 in equivalences:
  B.add((URIRef(class1), OWL.equivalentClass,URIRef(class2)))
for prop1, prop2 in equivalences:
  B.add((URIRef(prop1), OWL.equivalentProperty,URIRef(prop2)))

g.serialize(destination='/content/aligned_by_user.ttl', format='turtle')
# Out:
# <Graph identifier=N1497cf88f2bb4d38b1cfd76ab446a76c (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # task 6

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('/content/drive/MyDrive/output.csv')

# Extract the embeddings
embeddings = data.iloc[:, 1:].values

# Initialize a list for storing SSE values
sse = []

# Perform clustering for k between 2 and 20
for k in range(2, 21):
    # Initialize KMeans with the current value of k
    kmeans = KMeans(n_clusters=k)
    # Fit the embeddings to the model
    kmeans.fit(embeddings)
    # Append the SSE value to the list
    sse.append(kmeans.inertia_)

# Plot SSE values
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Elbow Method')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('/content/drive/MyDrive/output.csv')

# Extract the embeddings
embeddings = data.iloc[:, 1:].values

# Initialize lists for storing SSE and Silhouette scores
sse = []
silhouette_scores = []

# Perform clustering for k between 2 and 20
for k in range(2, 21):
    # Initialize KMeans with the current value of k
    kmeans = KMeans(n_clusters=k)
    # Fit the embeddings to the model
    kmeans.fit(embeddings)
    # Append the SSE value to the list
    sse.append(kmeans.inertia_)
    # Calculate the Silhouette score and append it to the list
    silhouette_scores.append(silhouette_score(embeddings, kmeans.labels_))

# Plot SSE values
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Elbow Method')
plt.show()

# Plot Silhouette scores
plt.plot(range(2, 21), silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('/content/drive/MyDrive/output.csv')

# Extract the embeddings
embeddings = data.iloc[:, 1:].values

# Perform clustering with k=8
kmeans = KMeans(n_clusters=8)
cluster_labels = kmeans.fit_predict(embeddings)

# Apply PCA for dimensionality reduction to 2D
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# Plot the clustering results on a 2D plot
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=cluster_labels)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Clustering Results (k=8)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Read the CSV file
#data = pd.read_csv('/content/drive/MyDrive/output.csv')

# Extract the embeddings
embeddings = data.iloc[:, 1:].values

# Perform clustering with k=15
kmeans = KMeans(n_clusters=15)
cluster_labels = kmeans.fit_predict(embeddings)

# Apply PCA for dimensionality reduction to 2D
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# %%
# Plot the clustering results on a 2D plot
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=cluster_labels)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Clustering Results (k=15)')
plt.show()

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Read the CSV file
#data = pd.read_csv('/content/drive/MyDrive/output.csv')

# Extract the embeddings
embeddings = data.iloc[:, 1:].values

# Perform clustering with k=2
kmeans = KMeans(n_clusters=2)
cluster_labels = kmeans.fit_predict(embeddings)

# Apply PCA for dimensionality reduction to 2D
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# Plot the clustering results on a 2D plot
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=cluster_labels)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Clustering Results (k=2)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data = data.rename(columns={data.columns[0]: 'embedding'})
data.head()
# Out:
#                                          embedding         0         1  \
# 0                                               of -0.409769  0.886151
# 1                                             type -0.736679  0.565664
# 2                                            pizza -0.010809  1.176755
# 3        http://www.semanticweb.org/owl2vec#typeOf  0.610288  0.142879
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  0.656674 -0.136439
#
#           2         3         4         5         6         7         8  ...  \
# 0  0.182495 -0.627666  0.593140  0.551254 -1.066917  0.045021 -0.633604  ...
# 1  0.254811 -1.107001  0.791414  0.929359 -1.526802  0.268393 -0.633156  ...
# 2  0.279866 -0.738134  0.162676  0.454871 -1.010887  0.155637 -0.410701  ...
# 3 -0.769991  0.828864 -0.039205 -0.181105 -0.913990 -0.006495 -0.067474  ...
# 4 -1.050983  1.159625 -0.121700  0.046027 -0.987411 -0.044839  0.084513  ...
#
#          90        91        92        93        94        95        96  \
# 0  0.366269  0.172051  1.175107 -0.431167  0.743886 -0.680531  0.223744
# 1  0.396563 -0.032871  1.323189 -0.521881  0.518183 -0.362549  0.372880
# 2  0.375989 -0.260217  0.780505 -0.648357  1.106418 -0.599670  0.014686
# 3  0.672256 -0.565384  0.238724 -0.169693  0.932245  0.612588  0.122182
# 4  0.417528  0.014978  0.607546 -0.195661  0.697807  0.136749 -0.026572
#
#          97        98        99
# 0  0.241587  0.398160 -0.058854
# 1  0.398472  0.155066  0.006514
# 2  0.350252  0.152177 -0.076184
# 3  1.190319 -0.724575 -0.436486
# 4  1.271083 -0.139468 -0.693450
#
# [5 rows x 101 columns]

# %%
import pandas as pd

# Read the CSV file into a DataFrame

# Define a function to retrieve the embedding for a given entity
def get_embedding(entity):
    embedding = data[data['embedding'] == entity].values[:, 1:].flatten()
    if len(embedding) > 0:
        return embedding
    else:
        return None

# Test the function
entity_name = 'margherita'
embedding = get_embedding(entity_name)

if embedding is not None:
    print(f"Embedding found for entity '{entity_name}': {embedding}")
else:
    print(f"No embedding found for entity '{entity_name}'")
# Out:
# Embedding found for entity 'margherita': [-0.90330523 0.7394789 0.47412163 0.18838903 -0.21315785 1.1000587
#  -0.48671755 0.7067824 -0.043227013 0.30160412 0.036673274 0.35353392
#  -0.29591385 -0.21899311 0.1859529 -0.38629165 -0.41257676 -0.9830062
#  0.39107108 0.5008457 -0.7510905 -0.06974218 -0.07735316 1.1725054
#  0.022743857 0.44085312 -0.14182943 0.7527927 0.587256 -0.62579453
#  -1.2131273 -0.15273029 -0.15025403 0.73014224 0.8381575 -1.5932864
#  0.20112906 -0.329726 -0.13647959 0.0157611 -0.058285628 0.97453094
#  0.35404804 -0.8270246 0.57804364 1.0531812 -0.46110415 1.2081242
#  0.8465455 -0.18759419 0.654666 -0.3338666 -1.7238941 0.033202678
#  0.7806755 0.047036797 0.16589133 0.2651749 -0.6556322 0.48066208
#  0.27154422 0.36355433 -0.385655 0.51798004 0.2425503 -0.023876999
#  -0.328722 0.38064495 0.36833328 -0.36140448 0.93799907 -0.28579277
#  -0.12850584 -0.21987931 -0.19258536 -0.22911851 -0.23532604 -0.9262261
#  -0.2037161 -0.07810496 0.30178446 -0.21756153 -0.098129354 -0.28979632
#  -0.51457703 0.5147229 -1.0270996 0.07224296 0.8688955 0.24956469
#  -0.18557581 0.04401348 1.0955815 0.044483595 0.56499535 -0.79124415
#  -0.31261757 0.19058938 -0.49876145 0.58133084]

# %%
import pandas as pd

# Read the CSV file into a DataFrame

# Define a function to return keys that include a given string
def get_keys_with_string(search_string):
    keys_with_string = data[data['embedding'].str.contains(search_string, case=False)]
    return keys_with_string['embedding'].tolist()

# Test the function
search_string = 'US'
keys_with_string = get_keys_with_string(search_string)

if len(keys_with_string) > 0:
    print(f"Keys including the string '{search_string}':")
    for key in keys_with_string:
        print(key)
else:
    print(f"No keys found including the string '{search_string}'")
# Out:
# Keys including the string 'US':
# USD
# usd
# us
# http://dbpedia.org/resource/US
# ruscello
# Mushrooms, olives, onions, green peppers, topped with sliced tomatoes.
# tuscan fig and oyster mushroom pizza
# small pepperoni, mushrooms, green peppers, bacon, sliced tomatoes
# Sausage, bacon and spinach over mozzarella topped with oven roasted eggs Surrounded by ricotta cheese (great to share)
# Sauteed with mushrooms, red peppers and olives in a fresh marinara sauce
# Mushrooms, black olives, tomatoes, peppers and onions baked with mozzarella cheese and pizza sauce.
# Mouse
# mushrooms, sausage, garlic, tomato sauce, mozzarella, scallions
# sausage, pepperoni, ham, bacon, and meatball.
# Usa
# house made caponata and tomato sauce with asiago cheese and prosciutto parma
# River House Bar & Grill
# tokai sushi
# brio tuscan grille - marlton - the promenade at sagemore
# olives, mushrooms, bell peppers, onions upon request cashews, tomatoes, artichoke hearts
# Fresh mozzarella, house made tomato sauce and Romano cheese topped with fresh basil.
# shredded chicken, chorizo or angus ground beef stuffed into two flat crisp tortillas. covered with melted queso cheese and topped with pico de gallo.
# chicken served with onions, olives mushrooms, and capers in a plum tomato sauce
# Blondie's Firehouse Pub
# mushrooms, olives, onions, green peppers, topped with sliced tomatoes.
# marinara, vegan cheese, veggie burger crumbles, zucchini, tomatoes, mushrooms, red onions, bell peppers
# spicy fennel sausage pizza
# tomato, olives, spinach, onion, mushrooms, red peppers.
# green pepper, mushrooms, onions, fresh tomatoes and zucchini.
# playhouse
# a cheese pizza with our famous pizza sauce.
# 286 Us Highway 46

# %%
import pandas as pd
from scipy.spatial.distance import cosine

# Read the CSV file into a DataFrame

# Define the pairs of entities you want to compare
entity_pairs = [
    ('margherita', 'pizza'),
    ('margherita', 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_type/margherita'),
    ('margherita', 'pizza margherita'),
    ('margherita', 'bianca'),
    ('margherita', 'US'),
    ('margherita','http://dbpedia.org/resource/US'),
    ('http://dbpedia.org/resource/US', 'US'),


]

# Iterate over the pairs of entities
for pair in entity_pairs:
    entity1, entity2 = pair

    # Extract the vectors for the entities
    vector1 = data[data['embedding'] == entity1].values[:, 1:].flatten()
    vector2 = data[data['embedding'] == entity2].values[:, 1:].flatten()

    # Calculate the cosine similarity between the vectors
    similarity_score = 1 - cosine(vector1, vector2)

    # Print the similarity score
    print(f"Similarity between {entity1} and {entity2}: {similarity_score}")
# Out:
# Similarity between margherita and pizza: 0.5790514051961504
# Similarity between margherita and http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_type/margherita: 0.3179901843147217
# Similarity between margherita and pizza margherita: 0.7940730842662989
# Similarity between margherita and bianca: 0.6125173372546684
# Similarity between margherita and US: 0.38876724626378323
# Similarity between margherita and http://dbpedia.org/resource/US: 0.28827882378274783
# Similarity between http://dbpedia.org/resource/US and US: 0.43053579612827253

# %%
# Test the function
entity_name = 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_type/margherita'
embedding = get_embedding(entity_name)

if embedding is not None:
    print(f"Embedding found for entity '{entity_name}': {embedding}")
else:
    print(f"No embedding found for entity '{entity_name}'")
# Out:
# Embedding found for entity 'http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_type/margherita': [0.002185421 -0.69867486 -1.3311447 1.0740854 -0.007635823 -0.18292688
#  -0.99322754 0.35173795 0.24342537 0.21575028 -0.10712048 0.52698314
#  -0.113644436 0.594556 -0.47903514 0.0024799537 -0.41484413 -0.75180286
#  -0.34945825 0.42536336 -0.26746014 0.11175962 0.24339087 1.1125425
#  -0.039544113 -0.00028989522 -0.12847298 0.44738427 0.46079332 0.39386198
#  0.050278552 0.16589282 -0.2728623 0.7344415 0.78032416 -0.9580098
#  0.724796 -0.6959314 -1.007071 -0.003151602 0.11975696 0.80089396
#  0.7002867 -0.60968125 0.873632 -0.3886309 0.63623494 0.10535488
#  0.30221415 -0.18667845 -0.48342642 -1.1877892 -0.31630474 -0.44608605
#  0.19589162 0.049703233 -0.46780756 0.6180284 -0.40065965 0.03480072
#  -0.3002782 0.355755 -0.19326288 0.7651957 -0.4765681 0.0356085 0.44141346
#  0.45478377 -0.029896796 -0.9131536 0.35819072 0.4325591 -0.58239543
#  -0.30963314 0.36384422 0.7705927 0.8107347 0.48466682 -0.22825673
#  0.557312 0.45606315 0.503075 -0.13184063 -0.8262978 -0.8271187 0.10037292
#  -0.88124233 -0.4588036 -0.75791866 0.18643743 -0.77520543 0.23260868
#  -0.17663579 -0.5630636 1.2000818 0.6883577 0.14980972 0.9651493
#  -1.0901057 -0.07387962]

# %%
# !pip install rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.1/528.1 kB 16.3 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-6.3.2

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery

# Create an RDF graph
g = Graph()
g.parse("/content/1.owl", format="xml")
# Out:
# <Graph identifier=N91006e660cb4428c8bdff707441d812a (<class 'rdflib.graph.Graph'>)>

# %%
G=Graph()
G.parse("https://protege.stanford.edu/ontologies/pizza/pizza.owl", format="xml")
# Out:
# <Graph identifier=Ne585dc2fe8434a7cb803d24e811660ea (<class 'rdflib.graph.Graph'>)>

# %%
G.serialize(format='turtle')
# Out:
# '@prefix : <http://www.co-ode.org/ontologies/pizza/pizza.owl#> .\n@prefix dc: <http://purl.org/dc/elements/1.1/> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix owl: <http://www.w3.org/2002/07/owl#> .\n@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix skos: <http://www.w3.org/2004/02/skos/core#> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\ndc:description a owl:AnnotationProperty .\n\ndc:title a owl:AnnotationProperty .\n\ndcterms:contributor a owl:AnnotationProperty .\n\ndcterms:license a owl:AnnotationProperty .\n\ndcterms:provenance a owl:AnnotationProperty .\n\n<http://www.co-ode.org/ontologies/pizza> a owl:Ontology ;\n    rdfs:label "pizza"^^xsd:string ;\n    dc:description """An ontology about pizzas and their toppings.\n\nThis is an example ontology that contains all constructs required for the various versions of the Pizza Tutorial run by Manchester University (see http://owl.cs.manchester.ac.uk/publications/talks-and-tutorials/protg-owl-tutorial)."""@en ;\n    dc:title "pizza"@en ;\n    dcterms:contributor "Alan Rector",\n        "Chris Wroe",\n        "Matthew Horridge",\n        "Nick Drummond",\n        "Robert Stevens" ;\n    dcterms:license "Creative Commons Attribution 3.0 (CC BY 3.0)"^^xsd:string ;\n    dcterms:provenance """v2.0 Added new annotations to the ontology using standard/well-know annotation properties\n\nv1.5. Removed protege.owl import and references. Made ontology URI date-independent\n\nv1.4. Added Food class (used in domain/range of hasIngredient), Added several hasCountryOfOrigin restrictions on pizzas, Made hasTopping invers functional"""@en ;\n    owl:versionIRI <http://www.co-ode.org/ontologies/pizza/2.0.0> ;\n    owl:versionInfo "2.0"^^xsd:string .\n\n:CheeseyPizza a owl:Class ;\n    rdfs:label "CheesyPizza"@en,\n        "PizzaComQueijo"@pt ;\n    owl:equivalentClass [ a owl:Class ;\n            owl:intersectionOf ( :Pizza [ a owl:Restriction ;\n                        owl:onProperty :hasTopping ;\n                        owl:someValuesFrom :CheeseTopping ] ) ] ;\n    skos:definition "Any pizza that has at least 1 cheese topping."@en ;\n    skos:prefLabel "Cheesy Pizza"@en .\n\n:CheeseyVegetableTopping a owl:Class ;\n    rdfs:label "CheesyVegetableTopping"@en,\n        "CoberturaDeQueijoComVegetais"@pt ;\n    rdfs:comment "This class will be unsatisfiable. This is because we have given it 2 disjoint parents, which means it could never have any instances (as nothing can be both a CheeseTopping and a VegetableTopping). NB Called ProbeInconsistentTopping in the ProtegeOWL Tutorial."@en ;\n    rdfs:subClassOf :CheeseTopping,\n        :VegetableTopping .\n\n:DeepPanBase a owl:Class ;\n    rdfs:label "DeepPanBase"@en,\n        "BaseEspessa"@pt ;\n    rdfs:subClassOf :PizzaBase ;\n    owl:disjointWith :ThinAndCrispyBase ;\n    skos:prefLabel "Deep Pan Base"@en .\n\n:InterestingPizza a owl:Class ;\n    rdfs:label "InterestingPizza"@en,\n        "PizzaInteressante"@pt ;\n    owl:equivalentClass [ a owl:Class ;\n            owl:intersectionOf ( :Pizza [ a owl:Restriction ;\n                        owl:minCardinality "3"^^xsd:nonNegativeInteger ;\n                        owl:onProperty :hasTopping ] ) ] ;\n    skos:definition "Any pizza that has at least 3 toppings. Note that this is a cardinality constraint on the hasTopping property and NOT a qualified cardinality constraint (QCR). A QCR would specify from which class the members in this relationship must be. eg has at least 3 toppings from PizzaTopping. This is currently not supported in OWL."@en ;\n    skos:prefLabel "Interesting Pizza"@en .\n\n:MeatyPizza a owl:Class ;\n    rdfs:label "MeatyPizza"@en,\n        "PizzaDeCarne"@pt ;\n    owl:equivalentClass [ a owl:Class ;\n            owl:intersectionOf ( :Pizza [ a owl:Restriction ;\n                        owl:onProperty :hasTopping ;\n                        owl:someValuesFrom :MeatTopping ] ) ] ;\ ...

# %%
from rdflib import Graph, Namespace

# Load the ontology into an RDF graph
# Get the namespaces from the graph
namespaces = G.namespaces()

# Print the defined namespaces
for prefix, uri in namespaces:
    print(f"Prefix: {prefix}, URI: {uri}")
# Out:
# Prefix: brick, URI: https://brickschema.org/schema/Brick#
# Prefix: csvw, URI: http://www.w3.org/ns/csvw#
# Prefix: dc, URI: http://purl.org/dc/elements/1.1/
# Prefix: dcat, URI: http://www.w3.org/ns/dcat#
# Prefix: dcmitype, URI: http://purl.org/dc/dcmitype/
# Prefix: dcterms, URI: http://purl.org/dc/terms/
# Prefix: dcam, URI: http://purl.org/dc/dcam/
# Prefix: doap, URI: http://usefulinc.com/ns/doap#
# Prefix: foaf, URI: http://xmlns.com/foaf/0.1/
# Prefix: geo, URI: http://www.opengis.net/ont/geosparql#
# Prefix: odrl, URI: http://www.w3.org/ns/odrl/2/
# Prefix: org, URI: http://www.w3.org/ns/org#
# Prefix: prof, URI: http://www.w3.org/ns/dx/prof/
# Prefix: prov, URI: http://www.w3.org/ns/prov#
# Prefix: qb, URI: http://purl.org/linked-data/cube#
# Prefix: schema, URI: https://schema.org/
# Prefix: sh, URI: http://www.w3.org/ns/shacl#
# Prefix: skos, URI: http://www.w3.org/2004/02/skos/core#
# Prefix: sosa, URI: http://www.w3.org/ns/sosa/
# Prefix: ssn, URI: http://www.w3.org/ns/ssn/
# Prefix: time, URI: http://www.w3.org/2006/time#
# Prefix: vann, URI: http://purl.org/vocab/vann/
# Prefix: void, URI: http://rdfs.org/ns/void#
# Prefix: wgs, URI: https://www.w3.org/2003/01/geo/wgs84_pos#
# Prefix: owl, URI: http://www.w3.org/2002/07/owl#
# Prefix: rdf, URI: http://www.w3.org/1999/02/22-rdf-syntax-ns#
# Prefix: rdfs, URI: http://www.w3.org/2000/01/rdf-schema#
# Prefix: xsd, URI: http://www.w3.org/2001/XMLSchema#
# Prefix: xml, URI: http://www.w3.org/XML/1998/namespace
# Prefix: , URI: http://www.co-ode.org/ontologies/pizza/pizza.owl#

# %%
from rdflib import Graph, Namespace

# Load the ontology into an RDF graph
g = Graph()
g.parse("your_ontology.owl", format="xml")  # Replace "your_ontology.owl" with the path to your ontology file

# Get the namespaces from the graph
namespaces = g.namespaces()

# Print the defined namespaces
for prefix, uri in namespaces:
    print(f"Prefix: {prefix}, URI: {uri}")
# Out:
# Prefix: brick, URI: https://brickschema.org/schema/Brick#
# Prefix: csvw, URI: http://www.w3.org/ns/csvw#
# Prefix: dc, URI: http://purl.org/dc/elements/1.1/
# Prefix: dcat, URI: http://www.w3.org/ns/dcat#
# Prefix: dcmitype, URI: http://purl.org/dc/dcmitype/
# Prefix: dcterms, URI: http://purl.org/dc/terms/
# Prefix: dcam, URI: http://purl.org/dc/dcam/
# Prefix: doap, URI: http://usefulinc.com/ns/doap#
# Prefix: foaf, URI: http://xmlns.com/foaf/0.1/
# Prefix: geo, URI: http://www.opengis.net/ont/geosparql#
# Prefix: odrl, URI: http://www.w3.org/ns/odrl/2/
# Prefix: org, URI: http://www.w3.org/ns/org#
# Prefix: prof, URI: http://www.w3.org/ns/dx/prof/
# Prefix: prov, URI: http://www.w3.org/ns/prov#
# Prefix: qb, URI: http://purl.org/linked-data/cube#
# Prefix: schema, URI: https://schema.org/
# Prefix: sh, URI: http://www.w3.org/ns/shacl#
# Prefix: skos, URI: http://www.w3.org/2004/02/skos/core#
# Prefix: sosa, URI: http://www.w3.org/ns/sosa/
# Prefix: ssn, URI: http://www.w3.org/ns/ssn/
# Prefix: time, URI: http://www.w3.org/2006/time#
# Prefix: vann, URI: http://purl.org/vocab/vann/
# Prefix: void, URI: http://rdfs.org/ns/void#
# Prefix: wgs, URI: https://www.w3.org/2003/01/geo/wgs84_pos#
# Prefix: owl, URI: http://www.w3.org/2002/07/owl#
# Prefix: rdf, URI: http://www.w3.org/1999/02/22-rdf-syntax-ns#
# Prefix: rdfs, URI: http://www.w3.org/2000/01/rdf-schema#
# Prefix: xsd, URI: http://www.w3.org/2001/XMLSchema#
# Prefix: xml, URI: http://www.w3.org/XML/1998/namespace
# Prefix: , URI: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/r#
# Prefix: e, URI: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/relations/
# Prefix: hadi, URI: http://www.city.ac.uk/ds/inm713/hadi_ghasemi/

# %% [markdown]
# # extention idea 1 (QA using chatgpt)

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.28.0

# %%
a="""for the rdf created by below codes, give me a sparqle query to fill in the query code for the question in rdflib:
import pandas as pd
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery
# Define the SPARQL query
sparql_query = "
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
PREFIX ...
SELECT ...
WHERE {
  ...
}
"
# Prepare the query
query = prepareQuery(sparql_query)
# Execute the query on the graph
results = g.query(query)
# Iterate over the results
for row in results:
  print(row)
  """
b="What is the price of the Margherita type Pizza at The Brentwood in USD?"

c="""
g = Graph()
n=Namespace('http://www.city.ac.uk/ds/inm713/hadi_ghasemi/')
def search_entity(entity):
    max_retries = 3
    retries = 0
    while retries < max_retries:
        try:
            uri = get_dbpedia_uri(entity)
            if uri:
                return uri
            time.sleep(1)  # add a delay to avoid too many requests
            uri = get_wikidata_uri(entity)
            if uri:
                return uri
            return None
        except HTTPError as ex:
            if ex.code == 429:
                print("Too many requests. Retrying in 10 seconds...")
                time.sleep(10)  # add a longer delay before retrying
                retries += 1
            else:
                raise
uri_dict={}
edge = URIRef(n + "in_country")
cnt=URIRef(n + "countries")
stts=URIRef(n + "states")
Cname=URIRef(n + "has_name")
Sname=URIRef(n + "has_name")
g.add((edge, RDF.type,OWL.ObjectProperty))
g.add((Cname, RDF.type,OWL.DatatypeProperty))
g.add((Sname, RDF.type,OWL.DatatypeProperty))
for index, row in country.iterrows():
    print(row["state"])
    State = row["state"]
    Country = row["country"]
    if Country not in uri_dict:
        uri_dict[Country] = search_entity(Country)
    if State not in uri_dict:
        uri_dict[State] = search_entity(State)
        if uri_dict[State] is None:
          uri_dict[State]=URIRef(n +"states/"+ urllib.parse.quote(row["state"]))
        print(uri_dict[State])
    if uri_dict[Country] is not None:
        target_uri = URIRef(uri_dict[Country])
        if uri_dict[State] is not None:
            source_uri = URIRef(uri_dict[State])
            g.add((target_uri,RDF.type,cnt))
            g.add((source_uri,RDF.type,stts))
            g.add((source_uri, edge, target_uri))
            g.add((target_uri,Cname,Literal(Country, datatype=XSD.string)))
            g.add((source_uri,Sname,Literal(State, datatype=XSD.string)))
edge = URIRef(n + "in_state")
Ctname=URIRef(n + "has_name")
cty=URIRef(n + "city")
g.add((edge, RDF.type,OWL.ObjectProperty))
g.add((Ctname, RDF.type,OWL.DatatypeProperty))
for index, row in state.iterrows():
    print(row["city"],'-',row["state"])
    City = row["city"]
    State = row["state"]
    if State not in uri_dict:
        uri_dict[State] = search_entity(State)
    if City not in uri_dict:
        uri_dict[City] = search_entity(City)
        if uri_dict[City] is None:
          uri_dict[City]=URIRef(n +"cities/"+ urllib.parse.quote(row["city"]))
    if uri_dict[State] is not None:
        target_uri = URIRef(uri_dict[State])
        if uri_dict[City] is not None:
            source_uri = URIRef(uri_dict[City])
            g.add((source_uri,RDF.type,cty))
            g.add((source_uri, edge, target_uri))
            g.add((source_uri,Ctname,Literal(City, datatype=XSD.string)))
edge = URIRef(n + "in_city")
restuarant=URIRef(n+"restaurant")
g.add((edge, RDF.type,OWL.ObjectProperty))
for index, row in city.iterrows():
    print(row["name"],'-',row["city"])
    City = row["city"]
    Name = row["name"]
    if City not in uri_dict:
        uri_dict[City] = search_entity(City)
    if uri_dict[City] is not None:
        target_uri = URIRef(uri_dict[City])
        source = URIRef(n +"restaurant/"+ urllib.parse.quote(Name))
        g.add((source,RDF.type, restuarant))
        g.add((source, edge, target_uri))
edge = URIRef(n + "has_address")
Rname=URIRef(n + "has_name")
g.add((edge, RDF.type,OWL.DatatypeProperty))
g.add((Rname, RDF.type,OWL.DatatypeProperty))
for index, row in address.iterrows():
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    target = Literal(row["address"], datatype=XSD.string)
    name=Literal(row["name"], datatype=XSD.string)
    g.add((source,edge, target))
    g.add((source,Rname, name))
edge = URIRef(n + "has_post_code")
g.add((edge, RDF.type,OWL.DatatypeProperty))
for index, row in postcode.iterrows():
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    target = Literal(row["postcode"], datatype=XSD.string)
    g.add((source,edge, target))
edge = URIRef(n + "restaurant_type")
g.add((edge, RDF.type,OWL.ObjectProperty))
Category=URIRef(n+"store")
for index, row in new_Categories.iterrows():
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    target = URIRef(n +"restaurant_types/"+ urllib.parse.quote(row["category"]))
    label = Literal(row["category"], datatype=XSD.string)
    g.add((target,RDFS.label , label))
    g.add((target,RDFS.subClassOf , Category))
    g.add((source,RDF.type, target))
edge = URIRef(n + "has_item")
Pname=URIRef(n + "has_name")
Pizza=URIRef(n+"food/pizza")
Food=URIRef(n+"food")
g.add((Pizza, RDFS.subClassOf,Food))
g.add((edge, RDF.type,OWL.ObjectProperty))
g.add((Pname, RDF.type,OWL.DatatypeProperty))
edge1 =RDF.type# URIRef(n + "pizza_type")
pizza_types=URIRef(n+"pizza_types")
g.add((edge1, RDF.type,OWL.ObjectProperty))
for index, row in pizza.iterrows():
    source = URIRef(n +"restaurant/"+ urllib.parse.quote(row["name"]))
    pizz = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    types=URIRef(n +"pizza_types/" +urllib.parse.quote(row["pizza_type"]) )
    label=Literal(row["pizza_type"], datatype=XSD.string)
    g.add((types,RDFS.subClassOf, Pizza))
    g.add((types,RDFS.label, label))
    g.add((pizz,edge1, types))
    name=Literal(row["menu item"], datatype=XSD.string)
    g.add((source,edge, pizz))
    g.add((pizz,Pname, name))
edge = URIRef(n + "has_price")
g.add((edge, RDF.type,OWL.DatatypeProperty))
for index, row in price.iterrows():
    source = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    target = Literal(row["item value"], datatype=XSD.float)
    g.add((source,edge, target))
edge = URIRef(n + "has_currency")
g.add((edge, RDF.type,OWL.DatatypeProperty))
for index, row in currency.iterrows():
    source = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    target = Literal(row["currency"], datatype=XSD.string)
    g.add((source,edge, target))
edge = URIRef(n + "has_description")
g.add((edge, RDF.type,OWL.DatatypeProperty))
for index, row in item_description.iterrows():
    source = URIRef(n +"food/pizza/"+urllib.parse.quote(row["pizza_type"])+'/'+ urllib.parse.quote(row["menu item"]) +"_of_"+urllib.parse.quote(row["name"]))
    target = Literal(row["item description"], datatype=XSD.string)
    g.add((source,edge, target))
"""

# %%
import openai

openai.api_key = "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"

response = openai.Completion.create(
  engine="text-davinci-003",
  prompt=a+b+c+"dont use prefix in sparqle",
  max_tokens=600
)

print(response.choices[0].text.strip())
# Out:
# query
#
# PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
# SELECT ?price
# WHERE {
#   ?restaurant n:has_name "The Brentwood".
#   ?restaurant n:has_item ?pizza.
#   ?pizza n:has_name "Margherita".
#   ?pizza n:has_price ?price.
#   ?pizza n:has_currency "USD".
# }

# %%
# !pip install rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 5.6 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-7.0.0

# %%
g = Graph()
g.parse("/content/RDF.owl", format="xml")
# Out:
# <Graph identifier=N1608f26e92a54aada1b8af4a455e4a93 (<class 'rdflib.graph.Graph'>)>

# %%
(response.choices[0].text.strip())
# Out:
# 'PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>\nSELECT ?price\nWHERE {\n  n:restaurant/The%20Brentwood n:has_item n:food/pizza/Margherita/Margherita_of_The%20Brentwood .\n  n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_price ?price .\n  n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_currency "USD" \n}'

# %%
# Provided SPARQL query
query = """PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>\nSELECT ?price\nWHERE {\n  n:restaurant/The%20Brentwood n:has_item n:food/pizza/Margherita/Margherita_of_The%20Brentwood .\n  n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_price ?price .\n  n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_currency "USD" \n}"""

# Decode and replace "\n" with actual line breaks
decoded_query = query.replace("\n", " ")

# Print the decoded query
print(decoded_query)
# Out:
# PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/> SELECT ?price WHERE {   n:restaurant/The%20Brentwood n:has_item n:food/pizza/Margherita/Margherita_of_The%20Brentwood .   n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_price ?price .   n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_currency "USD"  }

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery
A="""
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
SELECT ?price
WHERE {
  # ?restaurant n:has_name "Brentwood".
  # ?restaurant n:has_item ?pizza.
  # ?pizza n:has_price ?price.
  }
"""
# Define the SPARQL query
sparql_query = A

# Prepare the query
query = prepareQuery(A)

# Execute the query on the graph
results = g.query(query)


# Iterate over the results
for row in results:
  print(row)

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal
from rdflib.plugins.sparql import prepareQuery

# Define the SPARQL query without line breaks
A = """PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/> SELECT ?price WHERE { n:restaurant/The%20Brentwood n:has_item n:food/pizza/Margherita/Margherita_of_The%20Brentwood . n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_price ?price . n:food/pizza/Margherita/Margherita_of_The%20Brentwood n:has_currency "USD" }"""

# Create a graph (you should initialize 'g' with your RDF data)

# Define the SPARQL query
sparql_query = A
sparql_query = """
PREFIX n: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX pt: <http://www.city.ac.uk/ds/inm713/hadi_ghasemi/pizza_types/>

SELECT (AVG(?price) AS ?averagePrice)
WHERE {
  # ?pizza rdf:type pt:margherita;
  n:has_price ?price .
}"""
# Prepare the query
query = prepareQuery(sparql_query)

# Execute the query on the graph
results = g.query(query)

# Iterate over the results
for row in results:
    print(row['averagePrice'])
# Out:
# 15.542155172413802

# %%
A[69:85]
# Out:
# 'ce WHERE { n:res'
